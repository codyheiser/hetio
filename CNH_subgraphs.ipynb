# %% [markdown]
# ### Subgraph Generation
# Pull out subgraphs of shortest paths between nodes of interest
#
# ---

# %%
import random
import hetio.readwrite
import hetio.pathtools
import hetio.stats

# %%
# Read Hetionet v1.0
url = 'https://github.com/dhimmel/hetionet/raw/{}/{}'.format(
    '00bf0b6f8886821d91cfdf00eadad145a7a1b6da',
    'hetnet/json/hetionet-v1.0.json.bz2',
)
graph = hetio.readwrite.read_graph(url)
metagraph = graph.metagraph

# %%
# get list of possible metapaths up to len==4 for downstream calcs
possible_metapaths = metagraph.extract_metapaths(source='Gene', target='Gene', max_length=4)
#metagraph.extract_all_metapaths(max_length=4, exclude_inverts=True)

# %%
len(possible_metapaths)
# Out:
# 3977

# %%
possible_metapaths
# Out:
# [GcG,
#  GiG,
#  G<rG,
#  Gr>G,
#  GdAdG,
#  GdAeG,
#  GdAuG,
#  GeAdG,
#  GeAeG,
#  GeAuG,
#  GuAdG,
#  GuAeG,
#  GuAuG,
#  GpBPpG,
#  GpCCpG,
#  GbCbG,
#  GbCdG,
#  GbCuG,
#  GdCbG,
#  GdCdG,
#  GdCuG,
#  GuCbG,
#  GuCdG,
#  GuCuG,
#  GaDaG,
#  GaDdG,
#  GaDuG,
#  GdDaG,
#  GdDdG,
#  GdDuG,
#  GuDaG,
#  GuDdG,
#  GuDuG,
#  GcGcG,
#  GcGiG,
#  GcG<rG,
#  GcGr>G,
#  GiGcG,
#  GiGiG,
#  GiG<rG,
#  GiGr>G,
#  G<rGcG,
#  G<rGiG,
#  G<rG<rG,
#  G<rGr>G,
#  Gr>GcG,
#  Gr>GiG,
#  Gr>G<rG,
#  Gr>Gr>G,
#  GpMFpG,
#  GpPWpG,
#  GdAlDaG,
#  GdAlDdG,
#  GdAlDuG,
#  GdAdGcG,
#  GdAdGiG,
#  GdAdG<rG,
#  GdAdGr>G,
#  GdAeGcG,
#  GdAeGiG,
#  GdAeG<rG,
#  GdAeGr>G,
#  GdAuGcG,
#  GdAuGiG,
#  GdAuG<rG,
#  GdAuGr>G,
#  GeAlDaG,
#  GeAlDdG,
#  GeAlDuG,
#  GeAdGcG,
#  GeAdGiG,
#  GeAdG<rG,
#  GeAdGr>G,
#  GeAeGcG,
#  GeAeGiG,
#  GeAeG<rG,
#  GeAeGr>G,
#  GeAuGcG,
#  GeAuGiG,
#  GeAuG<rG,
#  GeAuGr>G,
#  GuAlDaG,
#  GuAlDdG,
#  GuAlDuG,
#  GuAdGcG,
#  GuAdGiG,
#  GuAdG<rG,
#  GuAdGr>G,
#  GuAeGcG,
#  GuAeGiG,
#  GuAeG<rG,
#  GuAeGr>G,
#  GuAuGcG,
#  GuAuGiG,
#  GuAuG<rG,
#  GuAuGr>G,
#  GpBPpGcG,
#  GpBPpGiG,
#  GpBPpG<rG,
#  GpBPpGr>G,
#  GpCCpGcG,
#  GpCCpGiG,
#  GpCCpG<rG,
#  GpCCpGr>G,
#  GbCrCbG,
#  GbCrCdG,
#  GbCrCuG,
#  GbCpDaG,
#  GbCpDdG,
#  GbCpDuG,
#  GbCtDaG,
#  GbCtDdG,
#  GbCtDuG,
#  GbCbGcG,
#  GbCbGiG,
#  GbCbG<rG,
#  GbCbGr>G,
#  GbCdGcG,
#  GbCdGiG,
#  GbCdG<rG,
#  GbCdGr>G,
#  GbCuGcG,
#  GbCuGiG,
#  GbCuG<rG,
#  GbCuGr>G,
#  GdCrCbG,
#  GdCrCdG,
#  GdCrCuG,
#  GdCpDaG,
#  GdCpDdG,
#  GdCpDuG,
#  GdCtDaG,
#  GdCtDdG,
#  GdCtDuG,
#  GdCbGcG,
#  GdCbGiG,
#  GdCbG<rG,
#  GdCbGr>G,
#  GdCdGcG,
#  GdCdGiG,
#  GdCdG<rG,
#  GdCdGr>G,
#  GdCuGcG,
#  GdCuGiG,
#  GdCuG<rG,
#  GdCuGr>G,
#  GuCrCbG,
#  GuCrCdG,
#  GuCrCuG,
#  GuCpDaG,
#  GuCpDdG,
#  GuCpDuG,
#  GuCtDaG,
#  GuCtDdG,
#  GuCtDuG,
#  GuCbGcG,
#  GuCbGiG,
#  GuCbG<rG,
#  GuCbGr>G,
#  GuCdGcG,
#  GuCdGiG,
#  GuCdG<rG,
#  GuCdGr>G,
#  GuCuGcG,
#  GuCuGiG,
#  GuCuG<rG,
#  GuCuGr>G,
#  GaDlAdG,
#  GaDlAeG,
#  GaDlAuG,
#  GaDpCbG,
#  GaDpCdG,
#  GaDpCuG,
#  GaDtCbG,
#  GaDtCdG,
#  GaDtCuG,
#  GaDrDaG,
#  GaDrDdG,
#  GaDrDuG,
#  GaDaGcG,
#  GaDaGiG,
#  GaDaG<rG,
#  GaDaGr>G,
#  GaDdGcG,
#  GaDdGiG,
#  GaDdG<rG,
#  GaDdGr>G,
#  GaDuGcG,
#  GaDuGiG,
#  GaDuG<rG,
#  GaDuGr>G,
#  GdDlAdG,
#  GdDlAeG,
#  GdDlAuG,
#  GdDpCbG,
#  GdDpCdG,
#  GdDpCuG,
#  GdDtCbG,
#  GdDtCdG,
#  GdDtCuG,
#  GdDrDaG,
#  GdDrDdG,
#  GdDrDuG,
#  GdDaGcG,
#  GdDaGiG,
#  GdDaG<rG,
#  GdDaGr>G,
#  GdDdGcG,
#  GdDdGiG,
#  GdDdG<rG,
#  GdDdGr>G,
#  GdDuGcG,
#  GdDuGiG,
#  GdDuG<rG,
#  GdDuGr>G,
#  GuDlAdG,
#  GuDlAeG,
#  GuDlAuG,
#  GuDpCbG,
#  GuDpCdG,
#  GuDpCuG,
#  GuDtCbG,
#  GuDtCdG,
#  GuDtCuG,
#  GuDrDaG,
#  GuDrDdG,
#  GuDrDuG,
#  GuDaGcG,
#  GuDaGiG,
#  GuDaG<rG,
#  GuDaGr>G,
#  GuDdGcG,
#  GuDdGiG,
#  GuDdG<rG,
#  GuDdGr>G,
#  GuDuGcG,
#  GuDuGiG,
#  GuDuG<rG,
#  GuDuGr>G,
#  GcGdAdG,
#  GcGdAeG,
#  GcGdAuG,
#  GcGeAdG,
#  GcGeAeG,
#  GcGeAuG,
#  GcGuAdG,
#  GcGuAeG,
#  GcGuAuG,
#  GcGpBPpG,
#  GcGpCCpG,
#  GcGbCbG,
#  GcGbCdG,
#  GcGbCuG,
#  GcGdCbG,
#  GcGdCdG,
#  GcGdCuG,
#  GcGuCbG,
#  GcGuCdG,
#  GcGuCuG,
#  GcGaDaG,
#  GcGaDdG,
#  GcGaDuG,
#  GcGdDaG,
#  GcGdDdG,
#  GcGdDuG,
#  GcGuDaG,
#  GcGuDdG,
#  GcGuDuG,
#  GcGcGcG,
#  GcGcGiG,
#  GcGcG<rG,
#  GcGcGr>G,
#  GcGiGcG,
#  GcGiGiG,
#  GcGiG<rG,
#  GcGiGr>G,
#  GcG<rGcG,
#  GcG<rGiG,
#  GcG<rG<rG,
#  GcG<rGr>G,
#  GcGr>GcG,
#  GcGr>GiG,
#  GcGr>G<rG,
#  GcGr>Gr>G,
#  GcGpMFpG,
#  GcGpPWpG,
#  GiGdAdG,
#  GiGdAeG,
#  GiGdAuG,
#  GiGeAdG,
#  GiGeAeG,
#  GiGeAuG,
#  GiGuAdG,
#  GiGuAeG,
#  GiGuAuG,
#  GiGpBPpG,
#  GiGpCCpG,
#  GiGbCbG,
#  GiGbCdG,
#  GiGbCuG,
#  GiGdCbG,
#  GiGdCdG,
#  GiGdCuG,
#  GiGuCbG,
#  GiGuCdG,
#  GiGuCuG,
#  GiGaDaG,
#  GiGaDdG,
#  GiGaDuG,
#  GiGdDaG,
#  GiGdDdG,
#  GiGdDuG,
#  GiGuDaG,
#  GiGuDdG,
#  GiGuDuG,
#  GiGcGcG,
#  GiGcGiG,
#  GiGcG<rG,
#  GiGcGr>G,
#  GiGiGcG,
#  GiGiGiG,
#  GiGiG<rG,
#  GiGiGr>G,
#  GiG<rGcG,
#  GiG<rGiG,
#  GiG<rG<rG,
#  GiG<rGr>G,
#  GiGr>GcG,
#  GiGr>GiG,
#  GiGr>G<rG,
#  GiGr>Gr>G,
#  GiGpMFpG,
#  GiGpPWpG,
#  G<rGdAdG,
#  G<rGdAeG,
#  G<rGdAuG,
#  G<rGeAdG,
#  G<rGeAeG,
#  G<rGeAuG,
#  G<rGuAdG,
#  G<rGuAeG,
#  G<rGuAuG,
#  G<rGpBPpG,
#  G<rGpCCpG,
#  G<rGbCbG,
#  G<rGbCdG,
#  G<rGbCuG,
#  G<rGdCbG,
#  G<rGdCdG,
#  G<rGdCuG,
#  G<rGuCbG,
#  G<rGuCdG,
#  G<rGuCuG,
#  G<rGaDaG,
#  G<rGaDdG,
#  G<rGaDuG,
#  G<rGdDaG,
#  G<rGdDdG,
#  G<rGdDuG,
#  G<rGuDaG,
#  G<rGuDdG,
#  G<rGuDuG,
#  G<rGcGcG,
#  G<rGcGiG,
#  G<rGcG<rG,
#  G<rGcGr>G,
#  G<rGiGcG,
#  G<rGiGiG,
#  G<rGiG<rG,
#  G<rGiGr>G,
#  G<rG<rGcG,
#  G<rG<rGiG,
#  G<rG<rG<rG,
#  G<rG<rGr>G,
#  G<rGr>GcG,
#  G<rGr>GiG,
#  G<rGr>G<rG,
#  G<rGr>Gr>G,
#  G<rGpMFpG,
#  G<rGpPWpG,
#  Gr>GdAdG,
#  Gr>GdAeG,
#  Gr>GdAuG,
#  Gr>GeAdG,
#  Gr>GeAeG,
#  Gr>GeAuG,
#  Gr>GuAdG,
#  Gr>GuAeG,
#  Gr>GuAuG,
#  Gr>GpBPpG,
#  Gr>GpCCpG,
#  Gr>GbCbG,
#  Gr>GbCdG,
#  Gr>GbCuG,
#  Gr>GdCbG,
#  Gr>GdCdG,
#  Gr>GdCuG,
#  Gr>GuCbG,
#  Gr>GuCdG,
#  Gr>GuCuG,
#  Gr>GaDaG,
#  Gr>GaDdG,
#  Gr>GaDuG,
#  Gr>GdDaG,
#  Gr>GdDdG,
#  Gr>GdDuG,
#  Gr>GuDaG,
#  Gr>GuDdG,
#  Gr>GuDuG,
#  Gr>GcGcG,
#  Gr>GcGiG,
#  Gr>GcG<rG,
#  Gr>GcGr>G,
#  Gr>GiGcG,
#  Gr>GiGiG,
#  Gr>GiG<rG,
#  Gr>GiGr>G,
#  Gr>G<rGcG,
#  Gr>G<rGiG,
#  Gr>G<rG<rG,
#  Gr>G<rGr>G,
#  Gr>Gr>GcG,
#  Gr>Gr>GiG,
#  Gr>Gr>G<rG,
#  Gr>Gr>Gr>G,
#  Gr>GpMFpG,
#  Gr>GpPWpG,
#  GpMFpGcG,
#  GpMFpGiG,
#  GpMFpG<rG,
#  GpMFpGr>G,
#  GpPWpGcG,
#  GpPWpGiG,
#  GpPWpG<rG,
#  GpPWpGr>G,
#  GdAlDlAdG,
#  GdAlDlAeG,
#  GdAlDlAuG,
#  GdAlDpCbG,
#  GdAlDpCdG,
#  GdAlDpCuG,
#  GdAlDtCbG,
#  GdAlDtCdG,
#  GdAlDtCuG,
#  GdAlDrDaG,
#  GdAlDrDdG,
#  GdAlDrDuG,
#  GdAlDaGcG,
#  GdAlDaGiG,
#  GdAlDaG<rG,
#  GdAlDaGr>G,
#  GdAlDdGcG,
#  GdAlDdGiG,
#  GdAlDdG<rG,
#  GdAlDdGr>G,
#  GdAlDuGcG,
#  GdAlDuGiG,
#  GdAlDuG<rG,
#  GdAlDuGr>G,
#  GdAdGdAdG,
#  GdAdGdAeG,
#  GdAdGdAuG,
#  GdAdGeAdG,
#  GdAdGeAeG,
#  GdAdGeAuG,
#  GdAdGuAdG,
#  GdAdGuAeG,
#  GdAdGuAuG,
#  GdAdGpBPpG,
#  GdAdGpCCpG,
#  GdAdGbCbG,
#  GdAdGbCdG,
#  GdAdGbCuG,
#  GdAdGdCbG,
#  GdAdGdCdG,
#  GdAdGdCuG,
#  GdAdGuCbG,
#  GdAdGuCdG,
#  GdAdGuCuG,
#  GdAdGaDaG,
#  GdAdGaDdG,
#  GdAdGaDuG,
#  GdAdGdDaG,
#  GdAdGdDdG,
#  GdAdGdDuG,
#  GdAdGuDaG,
#  GdAdGuDdG,
#  GdAdGuDuG,
#  GdAdGcGcG,
#  GdAdGcGiG,
#  GdAdGcG<rG,
#  GdAdGcGr>G,
#  GdAdGiGcG,
#  GdAdGiGiG,
#  GdAdGiG<rG,
#  GdAdGiGr>G,
#  GdAdG<rGcG,
#  GdAdG<rGiG,
#  GdAdG<rG<rG,
#  GdAdG<rGr>G,
#  GdAdGr>GcG,
#  GdAdGr>GiG,
#  GdAdGr>G<rG,
#  GdAdGr>Gr>G,
#  GdAdGpMFpG,
#  GdAdGpPWpG,
#  GdAeGdAdG,
#  GdAeGdAeG,
#  GdAeGdAuG,
#  GdAeGeAdG,
#  GdAeGeAeG,
#  GdAeGeAuG,
#  GdAeGuAdG,
#  GdAeGuAeG,
#  GdAeGuAuG,
#  GdAeGpBPpG,
#  GdAeGpCCpG,
#  GdAeGbCbG,
#  GdAeGbCdG,
#  GdAeGbCuG,
#  GdAeGdCbG,
#  GdAeGdCdG,
#  GdAeGdCuG,
#  GdAeGuCbG,
#  GdAeGuCdG,
#  GdAeGuCuG,
#  GdAeGaDaG,
#  GdAeGaDdG,
#  GdAeGaDuG,
#  GdAeGdDaG,
#  GdAeGdDdG,
#  GdAeGdDuG,
#  GdAeGuDaG,
#  GdAeGuDdG,
#  GdAeGuDuG,
#  GdAeGcGcG,
#  GdAeGcGiG,
#  GdAeGcG<rG,
#  GdAeGcGr>G,
#  GdAeGiGcG,
#  GdAeGiGiG,
#  GdAeGiG<rG,
#  GdAeGiGr>G,
#  GdAeG<rGcG,
#  GdAeG<rGiG,
#  GdAeG<rG<rG,
#  GdAeG<rGr>G,
#  GdAeGr>GcG,
#  GdAeGr>GiG,
#  GdAeGr>G<rG,
#  GdAeGr>Gr>G,
#  GdAeGpMFpG,
#  GdAeGpPWpG,
#  GdAuGdAdG,
#  GdAuGdAeG,
#  GdAuGdAuG,
#  GdAuGeAdG,
#  GdAuGeAeG,
#  GdAuGeAuG,
#  GdAuGuAdG,
#  GdAuGuAeG,
#  GdAuGuAuG,
#  GdAuGpBPpG,
#  GdAuGpCCpG,
#  GdAuGbCbG,
#  GdAuGbCdG,
#  GdAuGbCuG,
#  GdAuGdCbG,
#  GdAuGdCdG,
#  GdAuGdCuG,
#  GdAuGuCbG,
#  GdAuGuCdG,
#  GdAuGuCuG,
#  GdAuGaDaG,
#  GdAuGaDdG,
#  GdAuGaDuG,
#  GdAuGdDaG,
#  GdAuGdDdG,
#  GdAuGdDuG,
#  GdAuGuDaG,
#  GdAuGuDdG,
#  GdAuGuDuG,
#  GdAuGcGcG,
#  GdAuGcGiG,
#  GdAuGcG<rG,
#  GdAuGcGr>G,
#  GdAuGiGcG,
#  GdAuGiGiG,
#  GdAuGiG<rG,
#  GdAuGiGr>G,
#  GdAuG<rGcG,
#  GdAuG<rGiG,
#  GdAuG<rG<rG,
#  GdAuG<rGr>G,
#  GdAuGr>GcG,
#  GdAuGr>GiG,
#  GdAuGr>G<rG,
#  GdAuGr>Gr>G,
#  GdAuGpMFpG,
#  GdAuGpPWpG,
#  GeAlDlAdG,
#  GeAlDlAeG,
#  GeAlDlAuG,
#  GeAlDpCbG,
#  GeAlDpCdG,
#  GeAlDpCuG,
#  GeAlDtCbG,
#  GeAlDtCdG,
#  GeAlDtCuG,
#  GeAlDrDaG,
#  GeAlDrDdG,
#  GeAlDrDuG,
#  GeAlDaGcG,
#  GeAlDaGiG,
#  GeAlDaG<rG,
#  GeAlDaGr>G,
#  GeAlDdGcG,
#  GeAlDdGiG,
#  GeAlDdG<rG,
#  GeAlDdGr>G,
#  GeAlDuGcG,
#  GeAlDuGiG,
#  GeAlDuG<rG,
#  GeAlDuGr>G,
#  GeAdGdAdG,
#  GeAdGdAeG,
#  GeAdGdAuG,
#  GeAdGeAdG,
#  GeAdGeAeG,
#  GeAdGeAuG,
#  GeAdGuAdG,
#  GeAdGuAeG,
#  GeAdGuAuG,
#  GeAdGpBPpG,
#  GeAdGpCCpG,
#  GeAdGbCbG,
#  GeAdGbCdG,
#  GeAdGbCuG,
#  GeAdGdCbG,
#  GeAdGdCdG,
#  GeAdGdCuG,
#  GeAdGuCbG,
#  GeAdGuCdG,
#  GeAdGuCuG,
#  GeAdGaDaG,
#  GeAdGaDdG,
#  GeAdGaDuG,
#  GeAdGdDaG,
#  GeAdGdDdG,
#  GeAdGdDuG,
#  GeAdGuDaG,
#  GeAdGuDdG,
#  GeAdGuDuG,
#  GeAdGcGcG,
#  GeAdGcGiG,
#  GeAdGcG<rG,
#  GeAdGcGr>G,
#  GeAdGiGcG,
#  GeAdGiGiG,
#  GeAdGiG<rG,
#  GeAdGiGr>G,
#  GeAdG<rGcG,
#  GeAdG<rGiG,
#  GeAdG<rG<rG,
#  GeAdG<rGr>G,
#  GeAdGr>GcG,
#  GeAdGr>GiG,
#  GeAdGr>G<rG,
#  GeAdGr>Gr>G,
#  GeAdGpMFpG,
#  GeAdGpPWpG,
#  GeAeGdAdG,
#  GeAeGdAeG,
#  GeAeGdAuG,
#  GeAeGeAdG,
#  GeAeGeAeG,
#  GeAeGeAuG,
#  GeAeGuAdG,
#  GeAeGuAeG,
#  GeAeGuAuG,
#  GeAeGpBPpG,
#  GeAeGpCCpG,
#  GeAeGbCbG,
#  GeAeGbCdG,
#  GeAeGbCuG,
#  GeAeGdCbG,
#  GeAeGdCdG,
#  GeAeGdCuG,
#  GeAeGuCbG,
#  GeAeGuCdG,
#  GeAeGuCuG,
#  GeAeGaDaG,
#  GeAeGaDdG,
#  GeAeGaDuG,
#  GeAeGdDaG,
#  GeAeGdDdG,
#  GeAeGdDuG,
#  GeAeGuDaG,
#  GeAeGuDdG,
#  GeAeGuDuG,
#  GeAeGcGcG,
#  GeAeGcGiG,
#  GeAeGcG<rG,
#  GeAeGcGr>G,
#  GeAeGiGcG,
#  GeAeGiGiG,
#  GeAeGiG<rG,
#  GeAeGiGr>G,
#  GeAeG<rGcG,
#  GeAeG<rGiG,
#  GeAeG<rG<rG,
#  GeAeG<rGr>G,
#  GeAeGr>GcG,
#  GeAeGr>GiG,
#  GeAeGr>G<rG,
#  GeAeGr>Gr>G,
#  GeAeGpMFpG,
#  GeAeGpPWpG,
#  GeAuGdAdG,
#  GeAuGdAeG,
#  GeAuGdAuG,
#  GeAuGeAdG,
#  GeAuGeAeG,
#  GeAuGeAuG,
#  GeAuGuAdG,
#  GeAuGuAeG,
#  GeAuGuAuG,
#  GeAuGpBPpG,
#  GeAuGpCCpG,
#  GeAuGbCbG,
#  GeAuGbCdG,
#  GeAuGbCuG,
#  GeAuGdCbG,
#  GeAuGdCdG,
#  GeAuGdCuG,
#  GeAuGuCbG,
#  GeAuGuCdG,
#  GeAuGuCuG,
#  GeAuGaDaG,
#  GeAuGaDdG,
#  GeAuGaDuG,
#  GeAuGdDaG,
#  GeAuGdDdG,
#  GeAuGdDuG,
#  GeAuGuDaG,
#  GeAuGuDdG,
#  GeAuGuDuG,
#  GeAuGcGcG,
#  GeAuGcGiG,
#  GeAuGcG<rG,
#  GeAuGcGr>G,
#  GeAuGiGcG,
#  GeAuGiGiG,
#  GeAuGiG<rG,
#  GeAuGiGr>G,
#  GeAuG<rGcG,
#  GeAuG<rGiG,
#  GeAuG<rG<rG,
#  GeAuG<rGr>G,
#  GeAuGr>GcG,
#  GeAuGr>GiG,
#  GeAuGr>G<rG,
#  GeAuGr>Gr>G,
#  GeAuGpMFpG,
#  GeAuGpPWpG,
#  GuAlDlAdG,
#  GuAlDlAeG,
#  GuAlDlAuG,
#  GuAlDpCbG,
#  GuAlDpCdG,
#  GuAlDpCuG,
#  GuAlDtCbG,
#  GuAlDtCdG,
#  GuAlDtCuG,
#  GuAlDrDaG,
#  GuAlDrDdG,
#  GuAlDrDuG,
#  GuAlDaGcG,
#  GuAlDaGiG,
#  GuAlDaG<rG,
#  GuAlDaGr>G,
#  GuAlDdGcG,
#  GuAlDdGiG,
#  GuAlDdG<rG,
#  GuAlDdGr>G,
#  GuAlDuGcG,
#  GuAlDuGiG,
#  GuAlDuG<rG,
#  GuAlDuGr>G,
#  GuAdGdAdG,
#  GuAdGdAeG,
#  GuAdGdAuG,
#  GuAdGeAdG,
#  GuAdGeAeG,
#  GuAdGeAuG,
#  GuAdGuAdG,
#  GuAdGuAeG,
#  GuAdGuAuG,
#  GuAdGpBPpG,
#  GuAdGpCCpG,
#  GuAdGbCbG,
#  GuAdGbCdG,
#  GuAdGbCuG,
#  GuAdGdCbG,
#  GuAdGdCdG,
#  GuAdGdCuG,
#  GuAdGuCbG,
#  GuAdGuCdG,
#  GuAdGuCuG,
#  GuAdGaDaG,
#  GuAdGaDdG,
#  GuAdGaDuG,
#  GuAdGdDaG,
#  GuAdGdDdG,
#  GuAdGdDuG,
#  GuAdGuDaG,
#  GuAdGuDdG,
#  GuAdGuDuG,
#  GuAdGcGcG,
#  GuAdGcGiG,
#  GuAdGcG<rG,
#  GuAdGcGr>G,
#  GuAdGiGcG,
#  GuAdGiGiG,
#  GuAdGiG<rG,
#  GuAdGiGr>G,
#  GuAdG<rGcG,
#  GuAdG<rGiG,
#  GuAdG<rG<rG,
#  GuAdG<rGr>G,
#  GuAdGr>GcG,
#  GuAdGr>GiG,
#  GuAdGr>G<rG,
#  GuAdGr>Gr>G,
#  GuAdGpMFpG,
#  GuAdGpPWpG,
#  GuAeGdAdG,
#  GuAeGdAeG,
#  GuAeGdAuG,
#  GuAeGeAdG,
#  GuAeGeAeG,
#  GuAeGeAuG,
#  GuAeGuAdG,
#  GuAeGuAeG,
#  GuAeGuAuG,
#  GuAeGpBPpG,
#  GuAeGpCCpG,
#  GuAeGbCbG,
#  GuAeGbCdG,
#  GuAeGbCuG,
#  GuAeGdCbG,
#  GuAeGdCdG,
#  GuAeGdCuG,
#  GuAeGuCbG,
#  GuAeGuCdG,
#  GuAeGuCuG,
#  GuAeGaDaG,
#  GuAeGaDdG,
#  GuAeGaDuG,
#  GuAeGdDaG,
#  GuAeGdDdG,
#  GuAeGdDuG,
#  GuAeGuDaG,
#  GuAeGuDdG,
#  GuAeGuDuG,
#  GuAeGcGcG,
#  GuAeGcGiG,
#  GuAeGcG<rG,
#  GuAeGcGr>G,
#  GuAeGiGcG,
#  GuAeGiGiG,
#  GuAeGiG<rG,
#  GuAeGiGr>G,
#  GuAeG<rGcG,
#  GuAeG<rGiG,
#  GuAeG<rG<rG,
#  GuAeG<rGr>G,
#  GuAeGr>GcG,
#  GuAeGr>GiG,
#  GuAeGr>G<rG,
#  GuAeGr>Gr>G,
#  GuAeGpMFpG,
#  GuAeGpPWpG,
#  GuAuGdAdG,
#  GuAuGdAeG,
#  GuAuGdAuG,
#  GuAuGeAdG,
#  GuAuGeAeG,
#  GuAuGeAuG,
#  GuAuGuAdG,
#  GuAuGuAeG,
#  GuAuGuAuG,
#  GuAuGpBPpG,
#  GuAuGpCCpG,
#  GuAuGbCbG,
#  GuAuGbCdG,
#  GuAuGbCuG,
#  GuAuGdCbG,
#  GuAuGdCdG,
#  GuAuGdCuG,
#  GuAuGuCbG,
#  GuAuGuCdG,
#  GuAuGuCuG,
#  GuAuGaDaG,
#  GuAuGaDdG,
#  GuAuGaDuG,
#  GuAuGdDaG,
#  GuAuGdDdG,
#  GuAuGdDuG,
#  GuAuGuDaG,
#  GuAuGuDdG,
#  GuAuGuDuG,
#  GuAuGcGcG,
#  GuAuGcGiG,
#  GuAuGcG<rG,
#  GuAuGcGr>G,
#  GuAuGiGcG,
#  GuAuGiGiG,
#  GuAuGiG<rG,
#  GuAuGiGr>G,
#  GuAuG<rGcG,
#  GuAuG<rGiG,
#  GuAuG<rG<rG,
#  GuAuG<rGr>G,
#  GuAuGr>GcG,
#  GuAuGr>GiG,
#  GuAuGr>G<rG,
#  GuAuGr>Gr>G,
#  GuAuGpMFpG,
#  GuAuGpPWpG,
#  GpBPpGdAdG,
#  GpBPpGdAeG,
#  GpBPpGdAuG,
#  GpBPpGeAdG,
#  GpBPpGeAeG,
#  GpBPpGeAuG,
#  GpBPpGuAdG,
#  GpBPpGuAeG,
#  GpBPpGuAuG,
#  GpBPpGpBPpG,
#  GpBPpGpCCpG,
#  GpBPpGbCbG,
#  GpBPpGbCdG,
#  GpBPpGbCuG,
#  GpBPpGdCbG,
#  GpBPpGdCdG,
#  GpBPpGdCuG,
#  GpBPpGuCbG,
#  GpBPpGuCdG,
#  GpBPpGuCuG,
#  GpBPpGaDaG,
#  GpBPpGaDdG,
#  GpBPpGaDuG,
#  GpBPpGdDaG,
#  GpBPpGdDdG,
#  GpBPpGdDuG,
#  GpBPpGuDaG,
#  GpBPpGuDdG,
#  GpBPpGuDuG,
#  GpBPpGcGcG,
#  GpBPpGcGiG,
#  GpBPpGcG<rG,
#  GpBPpGcGr>G,
#  GpBPpGiGcG,
#  GpBPpGiGiG,
#  GpBPpGiG<rG,
#  GpBPpGiGr>G,
#  GpBPpG<rGcG,
#  GpBPpG<rGiG,
#  GpBPpG<rG<rG,
#  GpBPpG<rGr>G,
#  GpBPpGr>GcG,
#  GpBPpGr>GiG,
#  GpBPpGr>G<rG,
#  GpBPpGr>Gr>G,
#  GpBPpGpMFpG,
#  GpBPpGpPWpG,
#  GpCCpGdAdG,
#  GpCCpGdAeG,
#  GpCCpGdAuG,
#  GpCCpGeAdG,
#  GpCCpGeAeG,
#  GpCCpGeAuG,
#  GpCCpGuAdG,
#  GpCCpGuAeG,
#  GpCCpGuAuG,
#  GpCCpGpBPpG,
#  GpCCpGpCCpG,
#  GpCCpGbCbG,
#  GpCCpGbCdG,
#  GpCCpGbCuG,
#  GpCCpGdCbG,
#  GpCCpGdCdG,
#  GpCCpGdCuG,
#  GpCCpGuCbG,
#  GpCCpGuCdG,
#  GpCCpGuCuG,
#  GpCCpGaDaG,
#  GpCCpGaDdG,
#  GpCCpGaDuG,
#  ...]

# %%
# see how many gene nodes we have in the whole graph
graph.count_nodes(metanode='Gene')
# Out:
# 20945

# %% [markdown]
# #### 1. High Correlation Genes
# Genes ID-ed by Erin as highly correlated with CD4+ T-cell differentiation data from Sui Huang.

# %%
genes1 = ["TFE3","TYK2","H2A","H2B1","CPT1A","NUCB1","ENTPD4","DDX17","KLC1","JPH4","FAM214B","WDR48","CPT2"]

# %%
subgraph_nodes = [] # init list of nodes of interest
for n in graph.get_nodes():
    if n.name in genes1:
        subgraph_nodes.append(n)

# %%
subgraph_nodes
# Out:
# [Gene::10521,
#  Gene::57599,
#  Gene::4924,
#  Gene::84502,
#  Gene::1376,
#  Gene::3831,
#  Gene::7297,
#  Gene::80256,
#  Gene::7030,
#  Gene::1374,
#  Gene::9583]

# %%
subgraph1 = graph.get_subgraph(nodes=subgraph_nodes)

# %%
subgraph1.n_nodes
# Out:
# 11

# %%
graph.get_metaedge_to_edges('{}'.format(possible_metapaths[0]))
# Out:
# {<hetio.hetnet.MetaEdge at 0x1f2083198>: [<hetio.hetnet.Edge at 0x15619c400>,
#   <hetio.hetnet.Edge at 0x15619cb70>,
#   <hetio.hetnet.Edge at 0x15619cd30>,
#   <hetio.hetnet.Edge at 0x15619cda0>,
#   <hetio.hetnet.Edge at 0x1561a6160>,
#   <hetio.hetnet.Edge at 0x1561a61d0>,
#   <hetio.hetnet.Edge at 0x1561a6780>,
#   <hetio.hetnet.Edge at 0x1561a6b00>,
#   <hetio.hetnet.Edge at 0x1561a6e80>,
#   <hetio.hetnet.Edge at 0x1561af160>,
#   <hetio.hetnet.Edge at 0x1561b6b00>,
#   <hetio.hetnet.Edge at 0x1561bc2b0>,
#   <hetio.hetnet.Edge at 0x1561c5a20>,
#   <hetio.hetnet.Edge at 0x1561c5cc0>,
#   <hetio.hetnet.Edge at 0x1561cc080>,
#   <hetio.hetnet.Edge at 0x1561d3240>,
#   <hetio.hetnet.Edge at 0x1561d36a0>,
#   <hetio.hetnet.Edge at 0x1561d38d0>,
#   <hetio.hetnet.Edge at 0x1561da6a0>,
#   <hetio.hetnet.Edge at 0x1561e35c0>,
#   <hetio.hetnet.Edge at 0x1561e3be0>,
#   <hetio.hetnet.Edge at 0x1561e3d30>,
#   <hetio.hetnet.Edge at 0x1561ea8d0>,
#   <hetio.hetnet.Edge at 0x1561eae80>,
#   <hetio.hetnet.Edge at 0x1561f16a0>,
#   <hetio.hetnet.Edge at 0x1561f1780>,
#   <hetio.hetnet.Edge at 0x1561f9d30>,
#   <hetio.hetnet.Edge at 0x156200780>,
#   <hetio.hetnet.Edge at 0x156200be0>,
#   <hetio.hetnet.Edge at 0x156207400>,
#   <hetio.hetnet.Edge at 0x15620e550>,
#   <hetio.hetnet.Edge at 0x15620e940>,
#   <hetio.hetnet.Edge at 0x15620ebe0>,
#   <hetio.hetnet.Edge at 0x156217470>,
#   <hetio.hetnet.Edge at 0x156217be0>,
#   <hetio.hetnet.Edge at 0x15621ea20>,
#   <hetio.hetnet.Edge at 0x156225780>,
#   <hetio.hetnet.Edge at 0x15622e080>,
#   <hetio.hetnet.Edge at 0x15622e470>,
#   <hetio.hetnet.Edge at 0x15622e5c0>,
#   <hetio.hetnet.Edge at 0x156234240>,
#   <hetio.hetnet.Edge at 0x156234630>,
#   <hetio.hetnet.Edge at 0x156234d30>,
#   <hetio.hetnet.Edge at 0x15623c470>,
#   <hetio.hetnet.Edge at 0x156243400>,
#   <hetio.hetnet.Edge at 0x15624c7f0>,
#   <hetio.hetnet.Edge at 0x1562530f0>,
#   <hetio.hetnet.Edge at 0x156253b00>,
#   <hetio.hetnet.Edge at 0x15625b6a0>,
#   <hetio.hetnet.Edge at 0x15625ba90>,
#   <hetio.hetnet.Edge at 0x15625be80>,
#   <hetio.hetnet.Edge at 0x15625bf60>,
#   <hetio.hetnet.Edge at 0x1562648d0>,
#   <hetio.hetnet.Edge at 0x156264a20>,
#   <hetio.hetnet.Edge at 0x156272470>,
#   <hetio.hetnet.Edge at 0x1562726a0>,
#   <hetio.hetnet.Edge at 0x156272b00>,
#   <hetio.hetnet.Edge at 0x1562780f0>,
#   <hetio.hetnet.Edge at 0x156289a20>,
#   <hetio.hetnet.Edge at 0x156289d30>,
#   <hetio.hetnet.Edge at 0x156289fd0>,
#   <hetio.hetnet.Edge at 0x1562906a0>,
#   <hetio.hetnet.Edge at 0x1562a0710>,
#   <hetio.hetnet.Edge at 0x1562a0860>,
#   <hetio.hetnet.Edge at 0x1562a0c50>,
#   <hetio.hetnet.Edge at 0x1562a71d0>,
#   <hetio.hetnet.Edge at 0x1562a74e0>,
#   <hetio.hetnet.Edge at 0x1562a7780>,
#   <hetio.hetnet.Edge at 0x1562a7cc0>,
#   <hetio.hetnet.Edge at 0x1562ae5c0>,
#   <hetio.hetnet.Edge at 0x1562b7080>,
#   <hetio.hetnet.Edge at 0x1562b7160>,
#   <hetio.hetnet.Edge at 0x1562b77f0>,
#   <hetio.hetnet.Edge at 0x1562ce710>,
#   <hetio.hetnet.Edge at 0x1562ce8d0>,
#   <hetio.hetnet.Edge at 0x1562d5240>,
#   <hetio.hetnet.Edge at 0x1562d5da0>,
#   <hetio.hetnet.Edge at 0x1562ed780>,
#   <hetio.hetnet.Edge at 0x1562edfd0>,
#   <hetio.hetnet.Edge at 0x1562f3780>,
#   <hetio.hetnet.Edge at 0x1562f37f0>,
#   <hetio.hetnet.Edge at 0x1562fa470>,
#   <hetio.hetnet.Edge at 0x156303240>,
#   <hetio.hetnet.Edge at 0x15630a1d0>,
#   <hetio.hetnet.Edge at 0x15630a320>,
#   <hetio.hetnet.Edge at 0x15630a4e0>,
#   <hetio.hetnet.Edge at 0x15630a940>,
#   <hetio.hetnet.Edge at 0x15630ab00>,
#   <hetio.hetnet.Edge at 0x1563125c0>,
#   <hetio.hetnet.Edge at 0x1563199b0>,
#   <hetio.hetnet.Edge at 0x156322b00>,
#   <hetio.hetnet.Edge at 0x156329780>,
#   <hetio.hetnet.Edge at 0x156329c50>,
#   <hetio.hetnet.Edge at 0x1563310f0>,
#   <hetio.hetnet.Edge at 0x156331470>,
#   <hetio.hetnet.Edge at 0x1563316a0>,
#   <hetio.hetnet.Edge at 0x156331710>,
#   <hetio.hetnet.Edge at 0x156331f60>,
#   <hetio.hetnet.Edge at 0x1563391d0>,
#   <hetio.hetnet.Edge at 0x156339a90>,
#   <hetio.hetnet.Edge at 0x156340f60>,
#   <hetio.hetnet.Edge at 0x15634f710>,
#   <hetio.hetnet.Edge at 0x15634f780>,
#   <hetio.hetnet.Edge at 0x156358c50>,
#   <hetio.hetnet.Edge at 0x15635f470>,
#   <hetio.hetnet.Edge at 0x156366f60>,
#   <hetio.hetnet.Edge at 0x15636f160>,
#   <hetio.hetnet.Edge at 0x15636f2b0>,
#   <hetio.hetnet.Edge at 0x15636f8d0>,
#   <hetio.hetnet.Edge at 0x1563755c0>,
#   <hetio.hetnet.Edge at 0x15637c1d0>,
#   <hetio.hetnet.Edge at 0x15637c780>,
#   <hetio.hetnet.Edge at 0x15637cd30>,
#   <hetio.hetnet.Edge at 0x156384780>,
#   <hetio.hetnet.Edge at 0x156384d30>,
#   <hetio.hetnet.Edge at 0x15638d5c0>,
#   <hetio.hetnet.Edge at 0x15638dda0>,
#   <hetio.hetnet.Edge at 0x156394da0>,
#   <hetio.hetnet.Edge at 0x156394f60>,
#   <hetio.hetnet.Edge at 0x1563a5860>,
#   <hetio.hetnet.Edge at 0x1563a5b70>,
#   <hetio.hetnet.Edge at 0x1563ac630>,
#   <hetio.hetnet.Edge at 0x1563acb00>,
#   <hetio.hetnet.Edge at 0x1563acf60>,
#   <hetio.hetnet.Edge at 0x1563b2ef0>,
#   <hetio.hetnet.Edge at 0x1563ba2b0>,
#   <hetio.hetnet.Edge at 0x1563ba4e0>,
#   <hetio.hetnet.Edge at 0x1563c32b0>,
#   <hetio.hetnet.Edge at 0x1563ca8d0>,
#   <hetio.hetnet.Edge at 0x1563dac50>,
#   <hetio.hetnet.Edge at 0x1563e1470>,
#   <hetio.hetnet.Edge at 0x1563e8470>,
#   <hetio.hetnet.Edge at 0x1563e87f0>,
#   <hetio.hetnet.Edge at 0x1563e8a90>,
#   <hetio.hetnet.Edge at 0x1563ef400>,
#   <hetio.hetnet.Edge at 0x156441780>,
#   <hetio.hetnet.Edge at 0x1564419b0>,
#   <hetio.hetnet.Edge at 0x156448cc0>,
#   <hetio.hetnet.Edge at 0x156448e10>,
#   <hetio.hetnet.Edge at 0x156458fd0>,
#   <hetio.hetnet.Edge at 0x15645fa90>,
#   <hetio.hetnet.Edge at 0x15645fd30>,
#   <hetio.hetnet.Edge at 0x156466550>,
#   <hetio.hetnet.Edge at 0x1564668d0>,
#   <hetio.hetnet.Edge at 0x156466c50>,
#   <hetio.hetnet.Edge at 0x15646d400>,
#   <hetio.hetnet.Edge at 0x15646d9b0>,
#   <hetio.hetnet.Edge at 0x156476320>,
#   <hetio.hetnet.Edge at 0x15647d6a0>,
#   <hetio.hetnet.Edge at 0x15647de80>,
#   <hetio.hetnet.Edge at 0x156484c50>,
#   <hetio.hetnet.Edge at 0x15648d6a0>,
#   <hetio.hetnet.Edge at 0x15648d710>,
#   <hetio.hetnet.Edge at 0x156494390>,
#   <hetio.hetnet.Edge at 0x1564949b0>,
#   <hetio.hetnet.Edge at 0x156494e10>,
#   <hetio.hetnet.Edge at 0x15649be80>,
#   <hetio.hetnet.Edge at 0x1564ac470>,
#   <hetio.hetnet.Edge at 0x1564ac550>,
#   <hetio.hetnet.Edge at 0x1564ac5c0>,
#   <hetio.hetnet.Edge at 0x1564b36a0>,
#   <hetio.hetnet.Edge at 0x1564b3b00>,
#   <hetio.hetnet.Edge at 0x1564b9470>,
#   <hetio.hetnet.Edge at 0x1564b9a20>,
#   <hetio.hetnet.Edge at 0x1564b9b70>,
#   <hetio.hetnet.Edge at 0x1564c2da0>,
#   <hetio.hetnet.Edge at 0x1564c90f0>,
#   <hetio.hetnet.Edge at 0x1564c9400>,
#   <hetio.hetnet.Edge at 0x1564d0b00>,
#   <hetio.hetnet.Edge at 0x1564d0ef0>,
#   <hetio.hetnet.Edge at 0x1564d74e0>,
#   <hetio.hetnet.Edge at 0x1564e0550>,
#   <hetio.hetnet.Edge at 0x1564e0630>,
#   <hetio.hetnet.Edge at 0x1564e0780>,
#   <hetio.hetnet.Edge at 0x1564e0fd0>,
#   <hetio.hetnet.Edge at 0x1564e7da0>,
#   <hetio.hetnet.Edge at 0x1564ee160>,
#   <hetio.hetnet.Edge at 0x1564f70f0>,
#   <hetio.hetnet.Edge at 0x1564f77f0>,
#   <hetio.hetnet.Edge at 0x1564fdbe0>,
#   <hetio.hetnet.Edge at 0x1564fde80>,
#   <hetio.hetnet.Edge at 0x156514080>,
#   <hetio.hetnet.Edge at 0x156514160>,
#   <hetio.hetnet.Edge at 0x1565144e0>,
#   <hetio.hetnet.Edge at 0x156514710>,
#   <hetio.hetnet.Edge at 0x15651bcc0>,
#   <hetio.hetnet.Edge at 0x1565225c0>,
#   <hetio.hetnet.Edge at 0x156522ef0>,
#   <hetio.hetnet.Edge at 0x15652b240>,
#   <hetio.hetnet.Edge at 0x15652b6a0>,
#   <hetio.hetnet.Edge at 0x156532f60>,
#   <hetio.hetnet.Edge at 0x156538470>,
#   <hetio.hetnet.Edge at 0x156549f60>,
#   <hetio.hetnet.Edge at 0x156549fd0>,
#   <hetio.hetnet.Edge at 0x156550550>,
#   <hetio.hetnet.Edge at 0x156557b70>,
#   <hetio.hetnet.Edge at 0x156567470>,
#   <hetio.hetnet.Edge at 0x156567630>,
#   <hetio.hetnet.Edge at 0x156567710>,
#   <hetio.hetnet.Edge at 0x15656e710>,
#   <hetio.hetnet.Edge at 0x156574780>,
#   <hetio.hetnet.Edge at 0x156574cc0>,
#   <hetio.hetnet.Edge at 0x156574d30>,
#   <hetio.hetnet.Edge at 0x156574ef0>,
#   <hetio.hetnet.Edge at 0x15657d5c0>,
#   <hetio.hetnet.Edge at 0x15658b160>,
#   <hetio.hetnet.Edge at 0x15658b9b0>,
#   <hetio.hetnet.Edge at 0x15658bb00>,
#   <hetio.hetnet.Edge at 0x1565940f0>,
#   <hetio.hetnet.Edge at 0x1565944e0>,
#   <hetio.hetnet.Edge at 0x15659b400>,
#   <hetio.hetnet.Edge at 0x1565a3080>,
#   <hetio.hetnet.Edge at 0x1565a3160>,
#   <hetio.hetnet.Edge at 0x1565aa710>,
#   <hetio.hetnet.Edge at 0x1565aafd0>,
#   <hetio.hetnet.Edge at 0x1565b3320>,
#   <hetio.hetnet.Edge at 0x1565b37f0>,
#   <hetio.hetnet.Edge at 0x1565b3fd0>,
#   <hetio.hetnet.Edge at 0x1565b9b00>,
#   <hetio.hetnet.Edge at 0x1565c0240>,
#   <hetio.hetnet.Edge at 0x1565c0a90>,
#   <hetio.hetnet.Edge at 0x1565c0da0>,
#   <hetio.hetnet.Edge at 0x1565c9780>,
#   <hetio.hetnet.Edge at 0x1565d0470>,
#   <hetio.hetnet.Edge at 0x1565e7080>,
#   <hetio.hetnet.Edge at 0x1565e71d0>,
#   <hetio.hetnet.Edge at 0x1565e78d0>,
#   <hetio.hetnet.Edge at 0x1565e7f60>,
#   <hetio.hetnet.Edge at 0x1565ee630>,
#   <hetio.hetnet.Edge at 0x1565ee860>,
#   <hetio.hetnet.Edge at 0x1565eecc0>,
#   <hetio.hetnet.Edge at 0x1565f4080>,
#   <hetio.hetnet.Edge at 0x1565fd860>,
#   <hetio.hetnet.Edge at 0x156604630>,
#   <hetio.hetnet.Edge at 0x156604cc0>,
#   <hetio.hetnet.Edge at 0x15660b2b0>,
#   <hetio.hetnet.Edge at 0x15660bef0>,
#   <hetio.hetnet.Edge at 0x156612630>,
#   <hetio.hetnet.Edge at 0x15661b2b0>,
#   <hetio.hetnet.Edge at 0x15661b400>,
#   <hetio.hetnet.Edge at 0x15661b4e0>,
#   <hetio.hetnet.Edge at 0x1566224e0>,
#   <hetio.hetnet.Edge at 0x156622630>,
#   <hetio.hetnet.Edge at 0x1566229b0>,
#   <hetio.hetnet.Edge at 0x15662a0f0>,
#   <hetio.hetnet.Edge at 0x15662a160>,
#   <hetio.hetnet.Edge at 0x15662a1d0>,
#   <hetio.hetnet.Edge at 0x15662a630>,
#   <hetio.hetnet.Edge at 0x15662afd0>,
#   <hetio.hetnet.Edge at 0x1566328d0>,
#   <hetio.hetnet.Edge at 0x156632be0>,
#   <hetio.hetnet.Edge at 0x156639d30>,
#   <hetio.hetnet.Edge at 0x156640c50>,
#   <hetio.hetnet.Edge at 0x156640da0>,
#   <hetio.hetnet.Edge at 0x156640ef0>,
#   <hetio.hetnet.Edge at 0x156647d30>,
#   <hetio.hetnet.Edge at 0x156658a20>,
#   <hetio.hetnet.Edge at 0x156658b00>,
#   <hetio.hetnet.Edge at 0x156658e10>,
#   <hetio.hetnet.Edge at 0x15665f320>,
#   <hetio.hetnet.Edge at 0x15665fa20>,
#   <hetio.hetnet.Edge at 0x1566688d0>,
#   <hetio.hetnet.Edge at 0x15666f080>,
#   <hetio.hetnet.Edge at 0x156675b00>,
#   <hetio.hetnet.Edge at 0x15667c080>,
#   <hetio.hetnet.Edge at 0x15667cfd0>,
#   <hetio.hetnet.Edge at 0x156685470>,
#   <hetio.hetnet.Edge at 0x156685780>,
#   <hetio.hetnet.Edge at 0x15668c2b0>,
#   <hetio.hetnet.Edge at 0x15668c860>,
#   <hetio.hetnet.Edge at 0x15668c9b0>,
#   <hetio.hetnet.Edge at 0x1566937f0>,
#   <hetio.hetnet.Edge at 0x1566a35c0>,
#   <hetio.hetnet.Edge at 0x1566aa2b0>,
#   <hetio.hetnet.Edge at 0x1566b9630>,
#   <hetio.hetnet.Edge at 0x1566c0080>,
#   <hetio.hetnet.Edge at 0x1566c0630>,
#   <hetio.hetnet.Edge at 0x1566c08d0>,
#   <hetio.hetnet.Edge at 0x1566c7160>,
#   <hetio.hetnet.Edge at 0x1566c7c50>,
#   <hetio.hetnet.Edge at 0x1566c7ef0>,
#   <hetio.hetnet.Edge at 0x1566d08d0>,
#   <hetio.hetnet.Edge at 0x1566de630>,
#   <hetio.hetnet.Edge at 0x1566e50f0>,
#   <hetio.hetnet.Edge at 0x1566e5c50>,
#   <hetio.hetnet.Edge at 0x1566ee080>,
#   <hetio.hetnet.Edge at 0x1566f5390>,
#   <hetio.hetnet.Edge at 0x1566f58d0>,
#   <hetio.hetnet.Edge at 0x1566f5e10>,
#   <hetio.hetnet.Edge at 0x1566fc400>,
#   <hetio.hetnet.Edge at 0x1567050f0>,
#   <hetio.hetnet.Edge at 0x1567051d0>,
#   <hetio.hetnet.Edge at 0x156705710>,
#   <hetio.hetnet.Edge at 0x156705da0>,
#   <hetio.hetnet.Edge at 0x15670c5c0>,
#   <hetio.hetnet.Edge at 0x1567136a0>,
#   <hetio.hetnet.Edge at 0x156713cc0>,
#   <hetio.hetnet.Edge at 0x156713f60>,
#   <hetio.hetnet.Edge at 0x15671b240>,
#   <hetio.hetnet.Edge at 0x15671be80>,
#   <hetio.hetnet.Edge at 0x15671bf60>,
#   <hetio.hetnet.Edge at 0x156724400>,
#   <hetio.hetnet.Edge at 0x1567249b0>,
#   <hetio.hetnet.Edge at 0x15673a9b0>,
#   <hetio.hetnet.Edge at 0x15673ada0>,
#   <hetio.hetnet.Edge at 0x156758d30>,
#   <hetio.hetnet.Edge at 0x156758f60>,
#   <hetio.hetnet.Edge at 0x1567605c0>,
#   <hetio.hetnet.Edge at 0x156767c50>,
#   <hetio.hetnet.Edge at 0x15676f1d0>,
#   <hetio.hetnet.Edge at 0x156776ef0>,
#   <hetio.hetnet.Edge at 0x15677d5c0>,
#   <hetio.hetnet.Edge at 0x1567959b0>,
#   <hetio.hetnet.Edge at 0x15679cfd0>,
#   <hetio.hetnet.Edge at 0x1567a57f0>,
#   <hetio.hetnet.Edge at 0x1567abb00>,
#   <hetio.hetnet.Edge at 0x1567abc50>,
#   <hetio.hetnet.Edge at 0x1567b3e10>,
#   <hetio.hetnet.Edge at 0x1567ba4e0>,
#   <hetio.hetnet.Edge at 0x1567c3630>,
#   <hetio.hetnet.Edge at 0x1567c3c50>,
#   <hetio.hetnet.Edge at 0x1567da9b0>,
#   <hetio.hetnet.Edge at 0x1567dae10>,
#   <hetio.hetnet.Edge at 0x1567dafd0>,
#   <hetio.hetnet.Edge at 0x1567e1e10>,
#   <hetio.hetnet.Edge at 0x1567e1ef0>,
#   <hetio.hetnet.Edge at 0x1567e88d0>,
#   <hetio.hetnet.Edge at 0x1567ef6a0>,
#   <hetio.hetnet.Edge at 0x1567ef710>,
#   <hetio.hetnet.Edge at 0x1567efa90>,
#   <hetio.hetnet.Edge at 0x1567efcc0>,
#   <hetio.hetnet.Edge at 0x1567f8400>,
#   <hetio.hetnet.Edge at 0x1567ff1d0>,
#   <hetio.hetnet.Edge at 0x1567ff320>,
#   <hetio.hetnet.Edge at 0x1567ff4e0>,
#   <hetio.hetnet.Edge at 0x156806b70>,
#   <hetio.hetnet.Edge at 0x15680f080>,
#   <hetio.hetnet.Edge at 0x15680f0f0>,
#   <hetio.hetnet.Edge at 0x1568169b0>,
#   <hetio.hetnet.Edge at 0x156824e10>,
#   <hetio.hetnet.Edge at 0x15682c160>,
#   <hetio.hetnet.Edge at 0x1568332b0>,
#   <hetio.hetnet.Edge at 0x1568336a0>,
#   <hetio.hetnet.Edge at 0x156833e10>,
#   <hetio.hetnet.Edge at 0x15683b7f0>,
#   <hetio.hetnet.Edge at 0x15683ba90>,
#   <hetio.hetnet.Edge at 0x1568448d0>,
#   <hetio.hetnet.Edge at 0x156844cc0>,
#   <hetio.hetnet.Edge at 0x15684b160>,
#   <hetio.hetnet.Edge at 0x15684b470>,
#   <hetio.hetnet.Edge at 0x15684b550>,
#   <hetio.hetnet.Edge at 0x15684b6a0>,
#   <hetio.hetnet.Edge at 0x15684bb00>,
#   <hetio.hetnet.Edge at 0x15684bbe0>,
#   <hetio.hetnet.Edge at 0x15684bda0>,
#   <hetio.hetnet.Edge at 0x15684be80>,
#   <hetio.hetnet.Edge at 0x1568590f0>,
#   <hetio.hetnet.Edge at 0x1568595c0>,
#   <hetio.hetnet.Edge at 0x1568622b0>,
#   <hetio.hetnet.Edge at 0x156869c50>,
#   <hetio.hetnet.Edge at 0x1568805c0>,
#   <hetio.hetnet.Edge at 0x1568982b0>,
#   <hetio.hetnet.Edge at 0x15689fef0>,
#   <hetio.hetnet.Edge at 0x1568a6da0>,
#   <hetio.hetnet.Edge at 0x1568a6e80>,
#   <hetio.hetnet.Edge at 0x1568b64e0>,
#   <hetio.hetnet.Edge at 0x1568bc550>,
#   <hetio.hetnet.Edge at 0x1568cd9b0>,
#   <hetio.hetnet.Edge at 0x1568db320>,
#   <hetio.hetnet.Edge at 0x1568eb1d0>,
#   <hetio.hetnet.Edge at 0x1568ebb70>,
#   <hetio.hetnet.Edge at 0x1568ebe10>,
#   <hetio.hetnet.Edge at 0x1568f27f0>,
#   <hetio.hetnet.Edge at 0x1568fa320>,
#   <hetio.hetnet.Edge at 0x156901a90>,
#   <hetio.hetnet.Edge at 0x156908320>,
#   <hetio.hetnet.Edge at 0x156908860>,
#   <hetio.hetnet.Edge at 0x15690f2b0>,
#   <hetio.hetnet.Edge at 0x15690fef0>,
#   <hetio.hetnet.Edge at 0x1569182b0>,
#   <hetio.hetnet.Edge at 0x15691f240>,
#   <hetio.hetnet.Edge at 0x15691f4e0>,
#   <hetio.hetnet.Edge at 0x15691f8d0>,
#   <hetio.hetnet.Edge at 0x15691fef0>,
#   <hetio.hetnet.Edge at 0x156926550>,
#   <hetio.hetnet.Edge at 0x15692e550>,
#   <hetio.hetnet.Edge at 0x15692e630>,
#   <hetio.hetnet.Edge at 0x15692eb70>,
#   <hetio.hetnet.Edge at 0x1569365c0>,
#   <hetio.hetnet.Edge at 0x15693c4e0>,
#   <hetio.hetnet.Edge at 0x15693c550>,
#   <hetio.hetnet.Edge at 0x15693c9b0>,
#   <hetio.hetnet.Edge at 0x156944630>,
#   <hetio.hetnet.Edge at 0x156944710>,
#   <hetio.hetnet.Edge at 0x156944ef0>,
#   <hetio.hetnet.Edge at 0x15694d160>,
#   <hetio.hetnet.Edge at 0x15694d860>,
#   <hetio.hetnet.Edge at 0x15694d940>,
#   <hetio.hetnet.Edge at 0x156954710>,
#   <hetio.hetnet.Edge at 0x156954be0>,
#   <hetio.hetnet.Edge at 0x156954da0>,
#   <hetio.hetnet.Edge at 0x15695bda0>,
#   <hetio.hetnet.Edge at 0x15695be80>,
#   <hetio.hetnet.Edge at 0x156963080>,
#   <hetio.hetnet.Edge at 0x1569631d0>,
#   <hetio.hetnet.Edge at 0x156963240>,
#   <hetio.hetnet.Edge at 0x156963710>,
#   <hetio.hetnet.Edge at 0x156963b70>,
#   <hetio.hetnet.Edge at 0x156963d30>,
#   <hetio.hetnet.Edge at 0x15696b390>,
#   <hetio.hetnet.Edge at 0x156972940>,
#   <hetio.hetnet.Edge at 0x1569729b0>,
#   <hetio.hetnet.Edge at 0x156972d30>,
#   <hetio.hetnet.Edge at 0x1569818d0>,
#   <hetio.hetnet.Edge at 0x156981a90>,
#   <hetio.hetnet.Edge at 0x156981fd0>,
#   <hetio.hetnet.Edge at 0x1569880f0>,
#   <hetio.hetnet.Edge at 0x15698fbe0>,
#   <hetio.hetnet.Edge at 0x15698fcc0>,
#   <hetio.hetnet.Edge at 0x156997a90>,
#   <hetio.hetnet.Edge at 0x156997cc0>,
#   <hetio.hetnet.Edge at 0x1569b7080>,
#   <hetio.hetnet.Edge at 0x1569b7e80>,
#   <hetio.hetnet.Edge at 0x1569bd4e0>,
#   <hetio.hetnet.Edge at 0x1569bdef0>,
#   <hetio.hetnet.Edge at 0x1569c42b0>,
#   <hetio.hetnet.Edge at 0x1569c4710>,
#   <hetio.hetnet.Edge at 0x1569cc4e0>,
#   <hetio.hetnet.Edge at 0x1569cc780>,
#   <hetio.hetnet.Edge at 0x1569cca20>,
#   <hetio.hetnet.Edge at 0x1569d49b0>,
#   <hetio.hetnet.Edge at 0x1569db160>,
#   <hetio.hetnet.Edge at 0x1569db6a0>,
#   <hetio.hetnet.Edge at 0x1569ec6a0>,
#   <hetio.hetnet.Edge at 0x1569ec860>,
#   <hetio.hetnet.Edge at 0x1569ec8d0>,
#   <hetio.hetnet.Edge at 0x1569ec940>,
#   <hetio.hetnet.Edge at 0x1569f3320>,
#   <hetio.hetnet.Edge at 0x1569f34e0>,
#   <hetio.hetnet.Edge at 0x1569f3da0>,
#   <hetio.hetnet.Edge at 0x1569f9be0>,
#   <hetio.hetnet.Edge at 0x1569f9e10>,
#   <hetio.hetnet.Edge at 0x156a014e0>,
#   <hetio.hetnet.Edge at 0x156a019b0>,
#   <hetio.hetnet.Edge at 0x156a09080>,
#   <hetio.hetnet.Edge at 0x156a09fd0>,
#   <hetio.hetnet.Edge at 0x156a10630>,
#   <hetio.hetnet.Edge at 0x156a10710>,
#   <hetio.hetnet.Edge at 0x156a10c50>,
#   <hetio.hetnet.Edge at 0x156a20080>,
#   <hetio.hetnet.Edge at 0x156a201d0>,
#   <hetio.hetnet.Edge at 0x156a20fd0>,
#   <hetio.hetnet.Edge at 0x156a27860>,
#   <hetio.hetnet.Edge at 0x156a27cc0>,
#   <hetio.hetnet.Edge at 0x156a27e80>,
#   <hetio.hetnet.Edge at 0x156a2e160>,
#   <hetio.hetnet.Edge at 0x156a3d550>,
#   <hetio.hetnet.Edge at 0x156a3d8d0>,
#   <hetio.hetnet.Edge at 0x156a3def0>,
#   <hetio.hetnet.Edge at 0x156a4c240>,
#   <hetio.hetnet.Edge at 0x156a5d940>,
#   <hetio.hetnet.Edge at 0x156a5db70>,
#   <hetio.hetnet.Edge at 0x156a64080>,
#   <hetio.hetnet.Edge at 0x156a64240>,
#   <hetio.hetnet.Edge at 0x156a64630>,
#   <hetio.hetnet.Edge at 0x156a64f60>,
#   <hetio.hetnet.Edge at 0x156a6c710>,
#   <hetio.hetnet.Edge at 0x156a741d0>,
#   <hetio.hetnet.Edge at 0x156a742b0>,
#   <hetio.hetnet.Edge at 0x156a74cc0>,
#   <hetio.hetnet.Edge at 0x156a74da0>,
#   <hetio.hetnet.Edge at 0x156a7b7f0>,
#   <hetio.hetnet.Edge at 0x156a827f0>,
#   <hetio.hetnet.Edge at 0x156a82e80>,
#   <hetio.hetnet.Edge at 0x156a8b550>,
#   <hetio.hetnet.Edge at 0x156a8bef0>,
#   <hetio.hetnet.Edge at 0x156a92550>,
#   <hetio.hetnet.Edge at 0x156a92e10>,
#   <hetio.hetnet.Edge at 0x156a99400>,
#   <hetio.hetnet.Edge at 0x156a99550>,
#   <hetio.hetnet.Edge at 0x156aa2400>,
#   <hetio.hetnet.Edge at 0x156aa2710>,
#   <hetio.hetnet.Edge at 0x156aa2e80>,
#   <hetio.hetnet.Edge at 0x156aaa0f0>,
#   <hetio.hetnet.Edge at 0x156aaa400>,
#   <hetio.hetnet.Edge at 0x156aaa550>,
#   <hetio.hetnet.Edge at 0x156aaa5c0>,
#   <hetio.hetnet.Edge at 0x156aaabe0>,
#   <hetio.hetnet.Edge at 0x156ab16a0>,
#   <hetio.hetnet.Edge at 0x156ab1710>,
#   <hetio.hetnet.Edge at 0x156ab18d0>,
#   <hetio.hetnet.Edge at 0x156ab19b0>,
#   <hetio.hetnet.Edge at 0x156ab7550>,
#   <hetio.hetnet.Edge at 0x156ac0160>,
#   <hetio.hetnet.Edge at 0x156ac8080>,
#   <hetio.hetnet.Edge at 0x156ac81d0>,
#   <hetio.hetnet.Edge at 0x156acfef0>,
#   <hetio.hetnet.Edge at 0x156adf470>,
#   <hetio.hetnet.Edge at 0x156adf5c0>,
#   <hetio.hetnet.Edge at 0x156ae62b0>,
#   <hetio.hetnet.Edge at 0x156ae6470>,
#   <hetio.hetnet.Edge at 0x156ae6fd0>,
#   <hetio.hetnet.Edge at 0x156aee080>,
#   <hetio.hetnet.Edge at 0x156aee8d0>,
#   <hetio.hetnet.Edge at 0x156af69b0>,
#   <hetio.hetnet.Edge at 0x156afd630>,
#   <hetio.hetnet.Edge at 0x156afda20>,
#   <hetio.hetnet.Edge at 0x156b044e0>,
#   <hetio.hetnet.Edge at 0x156b04cc0>,
#   <hetio.hetnet.Edge at 0x156b04d30>,
#   <hetio.hetnet.Edge at 0x156b0c9b0>,
#   <hetio.hetnet.Edge at 0x156b0ce10>,
#   <hetio.hetnet.Edge at 0x156b15780>,
#   <hetio.hetnet.Edge at 0x156b15e10>,
#   <hetio.hetnet.Edge at 0x156b1c550>,
#   <hetio.hetnet.Edge at 0x156b1cbe0>,
#   <hetio.hetnet.Edge at 0x156b230f0>,
#   <hetio.hetnet.Edge at 0x156b23be0>,
#   <hetio.hetnet.Edge at 0x156b2de10>,
#   <hetio.hetnet.Edge at 0x156b3a080>,
#   <hetio.hetnet.Edge at 0x156b3a940>,
#   <hetio.hetnet.Edge at 0x156b3a9b0>,
#   <hetio.hetnet.Edge at 0x156b3acc0>,
#   <hetio.hetnet.Edge at 0x156b43080>,
#   <hetio.hetnet.Edge at 0x156b4bf60>,
#   <hetio.hetnet.Edge at 0x156b59fd0>,
#   <hetio.hetnet.Edge at 0x156b634e0>,
#   <hetio.hetnet.Edge at 0x156b63940>,
#   <hetio.hetnet.Edge at 0x156b6ad30>,
#   <hetio.hetnet.Edge at 0x156b71fd0>,
#   <hetio.hetnet.Edge at 0x156b79240>,
#   <hetio.hetnet.Edge at 0x156b79550>,
#   <hetio.hetnet.Edge at 0x156b799b0>,
#   <hetio.hetnet.Edge at 0x156b79e10>,
#   <hetio.hetnet.Edge at 0x156b81240>,
#   <hetio.hetnet.Edge at 0x156b819b0>,
#   <hetio.hetnet.Edge at 0x156b81be0>,
#   <hetio.hetnet.Edge at 0x156b88780>,
#   <hetio.hetnet.Edge at 0x156b98550>,
#   <hetio.hetnet.Edge at 0x156b98e80>,
#   <hetio.hetnet.Edge at 0x156b98ef0>,
#   <hetio.hetnet.Edge at 0x156b9f400>,
#   <hetio.hetnet.Edge at 0x156ba61d0>,
#   <hetio.hetnet.Edge at 0x156ba6860>,
#   <hetio.hetnet.Edge at 0x156bae5c0>,
#   <hetio.hetnet.Edge at 0x156bb5080>,
#   <hetio.hetnet.Edge at 0x156bb5be0>,
#   <hetio.hetnet.Edge at 0x156bbc940>,
#   <hetio.hetnet.Edge at 0x156bbcfd0>,
#   <hetio.hetnet.Edge at 0x156bcde10>,
#   <hetio.hetnet.Edge at 0x156bd4400>,
#   <hetio.hetnet.Edge at 0x156bd4e10>,
#   <hetio.hetnet.Edge at 0x156bd4e80>,
#   <hetio.hetnet.Edge at 0x156bdb630>,
#   <hetio.hetnet.Edge at 0x156be3860>,
#   <hetio.hetnet.Edge at 0x156be39b0>,
#   <hetio.hetnet.Edge at 0x156be3c50>,
#   <hetio.hetnet.Edge at 0x156bf3320>,
#   <hetio.hetnet.Edge at 0x156c092b0>,
#   <hetio.hetnet.Edge at 0x156c09f60>,
#   <hetio.hetnet.Edge at 0x156c11240>,
#   <hetio.hetnet.Edge at 0x156c11710>,
#   <hetio.hetnet.Edge at 0x156c11fd0>,
#   <hetio.hetnet.Edge at 0x156c19160>,
#   <hetio.hetnet.Edge at 0x156c195c0>,
#   <hetio.hetnet.Edge at 0x156c219b0>,
#   <hetio.hetnet.Edge at 0x156c21a20>,
#   <hetio.hetnet.Edge at 0x156c21da0>,
#   <hetio.hetnet.Edge at 0x156c2f630>,
#   <hetio.hetnet.Edge at 0x156c2fcc0>,
#   <hetio.hetnet.Edge at 0x156c2ffd0>,
#   <hetio.hetnet.Edge at 0x156c464e0>,
#   <hetio.hetnet.Edge at 0x156c57ef0>,
#   <hetio.hetnet.Edge at 0x156c5e0f0>,
#   <hetio.hetnet.Edge at 0x156c65080>,
#   <hetio.hetnet.Edge at 0x156c65a90>,
#   <hetio.hetnet.Edge at 0x156c6e320>,
#   <hetio.hetnet.Edge at 0x156c6e400>,
#   <hetio.hetnet.Edge at 0x156c6eb00>,
#   <hetio.hetnet.Edge at 0x156c6ef60>,
#   <hetio.hetnet.Edge at 0x156c7c390>,
#   <hetio.hetnet.Edge at 0x156c7c4e0>,
#   <hetio.hetnet.Edge at 0x156c7c6a0>,
#   <hetio.hetnet.Edge at 0x156c7cb70>,
#   <hetio.hetnet.Edge at 0x156c7cf60>,
#   <hetio.hetnet.Edge at 0x156c84fd0>,
#   <hetio.hetnet.Edge at 0x156c8c9b0>,
#   <hetio.hetnet.Edge at 0x156c8cb00>,
#   <hetio.hetnet.Edge at 0x156c93da0>,
#   <hetio.hetnet.Edge at 0x156c9a080>,
#   <hetio.hetnet.Edge at 0x156c9ac50>,
#   <hetio.hetnet.Edge at 0x156c9ada0>,
#   <hetio.hetnet.Edge at 0x156ca3400>,
#   <hetio.hetnet.Edge at 0x156ca3b00>,
#   <hetio.hetnet.Edge at 0x156cb8550>,
#   <hetio.hetnet.Edge at 0x156cc7160>,
#   <hetio.hetnet.Edge at 0x156cc7e10>,
#   <hetio.hetnet.Edge at 0x156ccfa90>,
#   <hetio.hetnet.Edge at 0x156cd8550>,
#   <hetio.hetnet.Edge at 0x156cd85c0>,
#   <hetio.hetnet.Edge at 0x156cdf780>,
#   <hetio.hetnet.Edge at 0x156ce60f0>,
#   <hetio.hetnet.Edge at 0x156ce6630>,
#   <hetio.hetnet.Edge at 0x156cef9b0>,
#   <hetio.hetnet.Edge at 0x156cf6240>,
#   <hetio.hetnet.Edge at 0x156cf6e10>,
#   <hetio.hetnet.Edge at 0x156cfde10>,
#   <hetio.hetnet.Edge at 0x156d0e2b0>,
#   <hetio.hetnet.Edge at 0x156d0e6a0>,
#   <hetio.hetnet.Edge at 0x156d0eda0>,
#   <hetio.hetnet.Edge at 0x156d0ee10>,
#   <hetio.hetnet.Edge at 0x156d15860>,
#   <hetio.hetnet.Edge at 0x156d159b0>,
#   <hetio.hetnet.Edge at 0x156d24390>,
#   <hetio.hetnet.Edge at 0x156d24a90>,
#   <hetio.hetnet.Edge at 0x156d2c240>,
#   <hetio.hetnet.Edge at 0x156d2c710>,
#   <hetio.hetnet.Edge at 0x156d2cb70>,
#   <hetio.hetnet.Edge at 0x156d32c50>,
#   <hetio.hetnet.Edge at 0x156d3a5c0>,
#   <hetio.hetnet.Edge at 0x156d3aa90>,
#   <hetio.hetnet.Edge at 0x156d432b0>,
#   <hetio.hetnet.Edge at 0x156d43320>,
#   <hetio.hetnet.Edge at 0x156d4a780>,
#   <hetio.hetnet.Edge at 0x156d4a940>,
#   <hetio.hetnet.Edge at 0x156d5a1d0>,
#   <hetio.hetnet.Edge at 0x156d5a2b0>,
#   <hetio.hetnet.Edge at 0x156d5a630>,
#   <hetio.hetnet.Edge at 0x156d5ac50>,
#   <hetio.hetnet.Edge at 0x156d5ada0>,
#   <hetio.hetnet.Edge at 0x156d63400>,
#   <hetio.hetnet.Edge at 0x156d63cc0>,
#   <hetio.hetnet.Edge at 0x156d6a550>,
#   <hetio.hetnet.Edge at 0x156d6ac50>,
#   <hetio.hetnet.Edge at 0x156d718d0>,
#   <hetio.hetnet.Edge at 0x156d71f60>,
#   <hetio.hetnet.Edge at 0x156d7ad30>,
#   <hetio.hetnet.Edge at 0x156d818d0>,
#   <hetio.hetnet.Edge at 0x156d81cc0>,
#   <hetio.hetnet.Edge at 0x156d91630>,
#   <hetio.hetnet.Edge at 0x156d91a20>,
#   <hetio.hetnet.Edge at 0x156d99160>,
#   <hetio.hetnet.Edge at 0x156d99400>,
#   <hetio.hetnet.Edge at 0x156d99710>,
#   <hetio.hetnet.Edge at 0x156d99a20>,
#   <hetio.hetnet.Edge at 0x156da82b0>,
#   <hetio.hetnet.Edge at 0x156da87f0>,
#   <hetio.hetnet.Edge at 0x156da8c50>,
#   <hetio.hetnet.Edge at 0x156da8e10>,
#   <hetio.hetnet.Edge at 0x156db7860>,
#   <hetio.hetnet.Edge at 0x156dbf5c0>,
#   <hetio.hetnet.Edge at 0x156dbfa90>,
#   <hetio.hetnet.Edge at 0x156dbfb70>,
#   <hetio.hetnet.Edge at 0x156dbfc50>,
#   <hetio.hetnet.Edge at 0x156dc7da0>,
#   <hetio.hetnet.Edge at 0x156dc7fd0>,
#   <hetio.hetnet.Edge at 0x156dcf7f0>,
#   <hetio.hetnet.Edge at 0x156dcfe80>,
#   <hetio.hetnet.Edge at 0x156dd6e10>,
#   <hetio.hetnet.Edge at 0x156de7fd0>,
#   <hetio.hetnet.Edge at 0x156deeb00>,
#   <hetio.hetnet.Edge at 0x156deebe0>,
#   <hetio.hetnet.Edge at 0x156dfc4e0>,
#   <hetio.hetnet.Edge at 0x156dfc710>,
#   <hetio.hetnet.Edge at 0x156dfc780>,
#   <hetio.hetnet.Edge at 0x156dfcc50>,
#   <hetio.hetnet.Edge at 0x156e04160>,
#   <hetio.hetnet.Edge at 0x156e0c320>,
#   <hetio.hetnet.Edge at 0x156e13e80>,
#   <hetio.hetnet.Edge at 0x156e1c0f0>,
#   <hetio.hetnet.Edge at 0x156e1c160>,
#   <hetio.hetnet.Edge at 0x156e244e0>,
#   <hetio.hetnet.Edge at 0x156e2b630>,
#   <hetio.hetnet.Edge at 0x156e2b7f0>,
#   <hetio.hetnet.Edge at 0x156e2bef0>,
#   <hetio.hetnet.Edge at 0x156e335c0>,
#   <hetio.hetnet.Edge at 0x156e33630>,
#   <hetio.hetnet.Edge at 0x156e33710>,
#   <hetio.hetnet.Edge at 0x156e33860>,
#   <hetio.hetnet.Edge at 0x156e3a550>,
#   <hetio.hetnet.Edge at 0x156e420f0>,
#   <hetio.hetnet.Edge at 0x156e42320>,
#   <hetio.hetnet.Edge at 0x156e42780>,
#   <hetio.hetnet.Edge at 0x156e42a90>,
#   <hetio.hetnet.Edge at 0x156e42c50>,
#   <hetio.hetnet.Edge at 0x156e49a20>,
#   <hetio.hetnet.Edge at 0x156e520f0>,
#   <hetio.hetnet.Edge at 0x156e52be0>,
#   <hetio.hetnet.Edge at 0x156e5a710>,
#   <hetio.hetnet.Edge at 0x156e625c0>,
#   <hetio.hetnet.Edge at 0x156e62b00>,
#   <hetio.hetnet.Edge at 0x156e62f60>,
#   <hetio.hetnet.Edge at 0x156e6a1d0>,
#   <hetio.hetnet.Edge at 0x156e6aa20>,
#   <hetio.hetnet.Edge at 0x156e78390>,
#   <hetio.hetnet.Edge at 0x156e78550>,
#   <hetio.hetnet.Edge at 0x156e78e80>,
#   <hetio.hetnet.Edge at 0x156e7f7f0>,
#   <hetio.hetnet.Edge at 0x156e88be0>,
#   <hetio.hetnet.Edge at 0x156e90b70>,
#   <hetio.hetnet.Edge at 0x156e9f320>,
#   <hetio.hetnet.Edge at 0x156e9f6a0>,
#   <hetio.hetnet.Edge at 0x156e9fbe0>,
#   <hetio.hetnet.Edge at 0x156e9fc50>,
#   <hetio.hetnet.Edge at 0x156ea8b70>,
#   <hetio.hetnet.Edge at 0x156ea8cc0>,
#   <hetio.hetnet.Edge at 0x156eaf6a0>,
#   <hetio.hetnet.Edge at 0x156eafc50>,
#   <hetio.hetnet.Edge at 0x156ebf240>,
#   <hetio.hetnet.Edge at 0x156ec62b0>,
#   <hetio.hetnet.Edge at 0x156ec66a0>,
#   <hetio.hetnet.Edge at 0x156ec6a90>,
#   <hetio.hetnet.Edge at 0x156ec6b70>,
#   <hetio.hetnet.Edge at 0x156ec6be0>,
#   <hetio.hetnet.Edge at 0x156ecd550>,
#   <hetio.hetnet.Edge at 0x156ee4d30>,
#   <hetio.hetnet.Edge at 0x156eebb00>,
#   <hetio.hetnet.Edge at 0x156eebcc0>,
#   <hetio.hetnet.Edge at 0x156efb7f0>,
#   <hetio.hetnet.Edge at 0x156efb8d0>,
#   <hetio.hetnet.Edge at 0x156efbb00>,
#   <hetio.hetnet.Edge at 0x156f020f0>,
#   <hetio.hetnet.Edge at 0x156f02a90>,
#   <hetio.hetnet.Edge at 0x156f0a0f0>,
#   <hetio.hetnet.Edge at 0x156f0a630>,
#   <hetio.hetnet.Edge at 0x156f0a780>,
#   <hetio.hetnet.Edge at 0x156f121d0>,
#   <hetio.hetnet.Edge at 0x156f12780>,
#   <hetio.hetnet.Edge at 0x156f210f0>,
#   <hetio.hetnet.Edge at 0x156f217f0>,
#   <hetio.hetnet.Edge at 0x156f2a400>,
#   <hetio.hetnet.Edge at 0x156f2a4e0>,
#   <hetio.hetnet.Edge at 0x156f32b00>,
#   <hetio.hetnet.Edge at 0x156f387f0>,
#   <hetio.hetnet.Edge at 0x156f389b0>,
#   <hetio.hetnet.Edge at 0x156f40160>,
#   <hetio.hetnet.Edge at 0x156f402b0>,
#   <hetio.hetnet.Edge at 0x156f49780>,
#   <hetio.hetnet.Edge at 0x156f50240>,
#   <hetio.hetnet.Edge at 0x156f508d0>,
#   <hetio.hetnet.Edge at 0x156f57d30>,
#   <hetio.hetnet.Edge at 0x156f601d0>,
#   <hetio.hetnet.Edge at 0x156f60240>,
#   <hetio.hetnet.Edge at 0x156f60780>,
#   <hetio.hetnet.Edge at 0x156f607f0>,
#   <hetio.hetnet.Edge at 0x156f6f550>,
#   <hetio.hetnet.Edge at 0x156f771d0>,
#   <hetio.hetnet.Edge at 0x156f778d0>,
#   <hetio.hetnet.Edge at 0x156f7f0f0>,
#   <hetio.hetnet.Edge at 0x156f7f4e0>,
#   <hetio.hetnet.Edge at 0x156f7f6a0>,
#   <hetio.hetnet.Edge at 0x156f86160>,
#   <hetio.hetnet.Edge at 0x156f86240>,
#   <hetio.hetnet.Edge at 0x156f86f60>,
#   <hetio.hetnet.Edge at 0x156f8d860>,
#   <hetio.hetnet.Edge at 0x156f9eb70>,
#   <hetio.hetnet.Edge at 0x156fa6390>,
#   <hetio.hetnet.Edge at 0x156fa6400>,
#   <hetio.hetnet.Edge at 0x156fa68d0>,
#   <hetio.hetnet.Edge at 0x156fae320>,
#   <hetio.hetnet.Edge at 0x156fb6390>,
#   <hetio.hetnet.Edge at 0x156fb6710>,
#   <hetio.hetnet.Edge at 0x156fd4080>,
#   <hetio.hetnet.Edge at 0x156fdb8d0>,
#   <hetio.hetnet.Edge at 0x156fdbcc0>,
#   <hetio.hetnet.Edge at 0x156fe3b00>,
#   <hetio.hetnet.Edge at 0x156feb160>,
#   <hetio.hetnet.Edge at 0x156feb8d0>,
#   <hetio.hetnet.Edge at 0x156febd30>,
#   <hetio.hetnet.Edge at 0x156ff2940>,
#   <hetio.hetnet.Edge at 0x156ff96a0>,
#   <hetio.hetnet.Edge at 0x156ff9780>,
#   <hetio.hetnet.Edge at 0x156ff97f0>,
#   <hetio.hetnet.Edge at 0x157002860>,
#   <hetio.hetnet.Edge at 0x157009080>,
#   <hetio.hetnet.Edge at 0x157021c50>,
#   <hetio.hetnet.Edge at 0x1570300f0>,
#   <hetio.hetnet.Edge at 0x1570309b0>,
#   <hetio.hetnet.Edge at 0x157030a20>,
#   <hetio.hetnet.Edge at 0x157030ef0>,
#   <hetio.hetnet.Edge at 0x157039160>,
#   <hetio.hetnet.Edge at 0x157039ef0>,
#   <hetio.hetnet.Edge at 0x1570402b0>,
#   <hetio.hetnet.Edge at 0x157040710>,
#   <hetio.hetnet.Edge at 0x157040940>,
#   <hetio.hetnet.Edge at 0x157040cc0>,
#   <hetio.hetnet.Edge at 0x157040e10>,
#   <hetio.hetnet.Edge at 0x1570470f0>,
#   <hetio.hetnet.Edge at 0x157047e10>,
#   <hetio.hetnet.Edge at 0x157050390>,
#   <hetio.hetnet.Edge at 0x157050400>,
#   <hetio.hetnet.Edge at 0x157058be0>,
#   <hetio.hetnet.Edge at 0x15705f0f0>,
#   <hetio.hetnet.Edge at 0x15705f470>,
#   <hetio.hetnet.Edge at 0x157070470>,
#   <hetio.hetnet.Edge at 0x157070b00>,
#   <hetio.hetnet.Edge at 0x1570771d0>,
#   <hetio.hetnet.Edge at 0x157077400>,
#   <hetio.hetnet.Edge at 0x1570775c0>,
#   <hetio.hetnet.Edge at 0x157085b70>,
#   <hetio.hetnet.Edge at 0x15708df60>,
#   <hetio.hetnet.Edge at 0x157094860>,
#   <hetio.hetnet.Edge at 0x157094cc0>,
#   <hetio.hetnet.Edge at 0x15709c390>,
#   <hetio.hetnet.Edge at 0x15709cfd0>,
#   <hetio.hetnet.Edge at 0x1570a5240>,
#   <hetio.hetnet.Edge at 0x1570a5320>,
#   <hetio.hetnet.Edge at 0x1570a5470>,
#   <hetio.hetnet.Edge at 0x1570a54e0>,
#   <hetio.hetnet.Edge at 0x1570a55c0>,
#   <hetio.hetnet.Edge at 0x1570ac390>,
#   <hetio.hetnet.Edge at 0x1570aca90>,
#   <hetio.hetnet.Edge at 0x1570ba390>,
#   <hetio.hetnet.Edge at 0x1570ca9b0>,
#   <hetio.hetnet.Edge at 0x1570d1400>,
#   <hetio.hetnet.Edge at 0x1570d1780>,
#   <hetio.hetnet.Edge at 0x1570da780>,
#   <hetio.hetnet.Edge at 0x1570da940>,
#   <hetio.hetnet.Edge at 0x1570e1c50>,
#   <hetio.hetnet.Edge at 0x1570e88d0>,
#   <hetio.hetnet.Edge at 0x1570e8e80>,
#   <hetio.hetnet.Edge at 0x1570f1630>,
#   <hetio.hetnet.Edge at 0x1570f8b70>,
#   <hetio.hetnet.Edge at 0x1570f8d30>,
#   <hetio.hetnet.Edge at 0x1570ff400>,
#   <hetio.hetnet.Edge at 0x1570ffb70>,
#   <hetio.hetnet.Edge at 0x157106160>,
#   <hetio.hetnet.Edge at 0x157106240>,
#   <hetio.hetnet.Edge at 0x157106320>,
#   <hetio.hetnet.Edge at 0x1571066a0>,
#   <hetio.hetnet.Edge at 0x157106fd0>,
#   <hetio.hetnet.Edge at 0x157110320>,
#   <hetio.hetnet.Edge at 0x15711ee10>,
#   <hetio.hetnet.Edge at 0x157126080>,
#   <hetio.hetnet.Edge at 0x157126320>,
#   <hetio.hetnet.Edge at 0x157126e10>,
#   <hetio.hetnet.Edge at 0x15712ec50>,
#   <hetio.hetnet.Edge at 0x157135400>,
#   <hetio.hetnet.Edge at 0x157135710>,
#   <hetio.hetnet.Edge at 0x157135860>,
#   <hetio.hetnet.Edge at 0x15713c400>,
#   <hetio.hetnet.Edge at 0x15713c470>,
#   <hetio.hetnet.Edge at 0x157145080>,
#   <hetio.hetnet.Edge at 0x1571459b0>,
#   <hetio.hetnet.Edge at 0x15714d7f0>,
#   <hetio.hetnet.Edge at 0x1571545c0>,
#   <hetio.hetnet.Edge at 0x157154d30>,
#   <hetio.hetnet.Edge at 0x157164550>,
#   <hetio.hetnet.Edge at 0x15716c390>,
#   <hetio.hetnet.Edge at 0x15716c630>,
#   <hetio.hetnet.Edge at 0x15716c6a0>,
#   <hetio.hetnet.Edge at 0x15717ce80>,
#   <hetio.hetnet.Edge at 0x1571835c0>,
#   <hetio.hetnet.Edge at 0x1571838d0>,
#   <hetio.hetnet.Edge at 0x157183ef0>,
#   <hetio.hetnet.Edge at 0x15718a5c0>,
#   <hetio.hetnet.Edge at 0x157193240>,
#   <hetio.hetnet.Edge at 0x157193b00>,
#   <hetio.hetnet.Edge at 0x15719b550>,
#   <hetio.hetnet.Edge at 0x1571a32b0>,
#   <hetio.hetnet.Edge at 0x1571b4fd0>,
#   <hetio.hetnet.Edge at 0x1571ba4e0>,
#   <hetio.hetnet.Edge at 0x1571bac50>,
#   <hetio.hetnet.Edge at 0x1571ca240>,
#   <hetio.hetnet.Edge at 0x1571ca860>,
#   <hetio.hetnet.Edge at 0x1571ca940>,
#   <hetio.hetnet.Edge at 0x1571caf60>,
#   <hetio.hetnet.Edge at 0x1571d2780>,
#   <hetio.hetnet.Edge at 0x1571d9e80>,
#   <hetio.hetnet.Edge at 0x1571e0320>,
#   <hetio.hetnet.Edge at 0x1571e0860>,
#   <hetio.hetnet.Edge at 0x1571e09b0>,
#   <hetio.hetnet.Edge at 0x1571e9a20>,
#   <hetio.hetnet.Edge at 0x1571e9f60>,
#   <hetio.hetnet.Edge at 0x1571f0160>,
#   <hetio.hetnet.Edge at 0x1571f0400>,
#   <hetio.hetnet.Edge at 0x1571f0e80>,
#   <hetio.hetnet.Edge at 0x1571f74e0>,
#   <hetio.hetnet.Edge at 0x1571f7be0>,
#   <hetio.hetnet.Edge at 0x1571ff710>,
#   <hetio.hetnet.Edge at 0x1571ffa90>,
#   <hetio.hetnet.Edge at 0x1571ffda0>,
#   <hetio.hetnet.Edge at 0x1572150f0>,
#   <hetio.hetnet.Edge at 0x157215c50>,
#   <hetio.hetnet.Edge at 0x15721f1d0>,
#   <hetio.hetnet.Edge at 0x157226f60>,
#   <hetio.hetnet.Edge at 0x15722e400>,
#   <hetio.hetnet.Edge at 0x15722e550>,
#   <hetio.hetnet.Edge at 0x15722ec50>,
#   <hetio.hetnet.Edge at 0x157236780>,
#   <hetio.hetnet.Edge at 0x1572369b0>,
#   <hetio.hetnet.Edge at 0x15723d160>,
#   <hetio.hetnet.Edge at 0x15723dcc0>,
#   <hetio.hetnet.Edge at 0x157245470>,
#   <hetio.hetnet.Edge at 0x157245860>,
#   <hetio.hetnet.Edge at 0x157245e10>,
#   <hetio.hetnet.Edge at 0x157255c50>,
#   <hetio.hetnet.Edge at 0x15725c2b0>,
#   <hetio.hetnet.Edge at 0x15725c4e0>,
#   <hetio.hetnet.Edge at 0x15725cbe0>,
#   <hetio.hetnet.Edge at 0x15725ccc0>,
#   <hetio.hetnet.Edge at 0x15725cfd0>,
#   <hetio.hetnet.Edge at 0x1572649b0>,
#   <hetio.hetnet.Edge at 0x15726cb00>,
#   <hetio.hetnet.Edge at 0x157274080>,
#   <hetio.hetnet.Edge at 0x157274550>,
#   <hetio.hetnet.Edge at 0x1572746a0>,
#   <hetio.hetnet.Edge at 0x15727b5c0>,
#   <hetio.hetnet.Edge at 0x15727bb00>,
#   <hetio.hetnet.Edge at 0x15727be80>,
#   <hetio.hetnet.Edge at 0x157283390>,
#   <hetio.hetnet.Edge at 0x157283630>,
#   <hetio.hetnet.Edge at 0x15728c1d0>,
#   <hetio.hetnet.Edge at 0x1572930f0>,
#   <hetio.hetnet.Edge at 0x1572931d0>,
#   <hetio.hetnet.Edge at 0x1572936a0>,
#   <hetio.hetnet.Edge at 0x157293be0>,
#   <hetio.hetnet.Edge at 0x15729b160>,
#   <hetio.hetnet.Edge at 0x15729b470>,
#   <hetio.hetnet.Edge at 0x1572a32b0>,
#   <hetio.hetnet.Edge at 0x1572a39b0>,
#   <hetio.hetnet.Edge at 0x1572a3cc0>,
#   <hetio.hetnet.Edge at 0x1572a3f60>,
#   <hetio.hetnet.Edge at 0x1572abda0>,
#   <hetio.hetnet.Edge at 0x1572b3080>,
#   <hetio.hetnet.Edge at 0x1572b3940>,
#   <hetio.hetnet.Edge at 0x1572ba470>,
#   <hetio.hetnet.Edge at 0x1572c2160>,
#   <hetio.hetnet.Edge at 0x1572c9470>,
#   <hetio.hetnet.Edge at 0x1572d0470>,
#   <hetio.hetnet.Edge at 0x1572d95c0>,
#   <hetio.hetnet.Edge at 0x1572e82b0>,
#   <hetio.hetnet.Edge at 0x1572e8860>,
#   <hetio.hetnet.Edge at 0x1572e8ef0>,
#   <hetio.hetnet.Edge at 0x1572e8fd0>,
#   <hetio.hetnet.Edge at 0x1572f9160>,
#   <hetio.hetnet.Edge at 0x1572f9b70>,
#   <hetio.hetnet.Edge at 0x1572ff240>,
#   <hetio.hetnet.Edge at 0x157307940>,
#   <hetio.hetnet.Edge at 0x15730ffd0>,
#   <hetio.hetnet.Edge at 0x157317080>,
#   <hetio.hetnet.Edge at 0x1573172b0>,
#   <hetio.hetnet.Edge at 0x15731e470>,
#   <hetio.hetnet.Edge at 0x157326cc0>,
#   <hetio.hetnet.Edge at 0x157326d30>,
#   <hetio.hetnet.Edge at 0x157336160>,
#   <hetio.hetnet.Edge at 0x1573364e0>,
#   <hetio.hetnet.Edge at 0x157336710>,
#   <hetio.hetnet.Edge at 0x157336e10>,
#   <hetio.hetnet.Edge at 0x157336e80>,
#   <hetio.hetnet.Edge at 0x15733c710>,
#   <hetio.hetnet.Edge at 0x15733cc50>,
#   <hetio.hetnet.Edge at 0x157344080>,
#   <hetio.hetnet.Edge at 0x15734def0>,
#   <hetio.hetnet.Edge at 0x157354940>,
#   <hetio.hetnet.Edge at 0x157365a90>,
#   <hetio.hetnet.Edge at 0x15736c320>,
#   <hetio.hetnet.Edge at 0x15736ce10>,
#   <hetio.hetnet.Edge at 0x157374240>,
#   <hetio.hetnet.Edge at 0x157374c50>,
#   <hetio.hetnet.Edge at 0x15737c4e0>,
#   <hetio.hetnet.Edge at 0x15737c6a0>,
#   <hetio.hetnet.Edge at 0x157383320>,
#   <hetio.hetnet.Edge at 0x15738a5c0>,
#   <hetio.hetnet.Edge at 0x157391e80>,
#   <hetio.hetnet.Edge at 0x15739b160>,
#   <hetio.hetnet.Edge at 0x15739b1d0>,
#   <hetio.hetnet.Edge at 0x15739b390>,
#   <hetio.hetnet.Edge at 0x15739be10>,
#   <hetio.hetnet.Edge at 0x1573a2ef0>,
#   <hetio.hetnet.Edge at 0x1573a91d0>,
#   <hetio.hetnet.Edge at 0x1573a99b0>,
#   <hetio.hetnet.Edge at 0x1573b1b00>,
#   <hetio.hetnet.Edge at 0x1573b1da0>,
#   <hetio.hetnet.Edge at 0x1573b92b0>,
#   <hetio.hetnet.Edge at 0x1573c7b00>,
#   <hetio.hetnet.Edge at 0x1573d01d0>,
#   <hetio.hetnet.Edge at 0x1573d0550>,
#   <hetio.hetnet.Edge at 0x1573d0d30>,
#   <hetio.hetnet.Edge at 0x1573d74e0>,
#   <hetio.hetnet.Edge at 0x1573d7cc0>,
#   <hetio.hetnet.Edge at 0x1573d7ef0>,
#   <hetio.hetnet.Edge at 0x1573df8d0>,
#   <hetio.hetnet.Edge at 0x1573e70f0>,
#   <hetio.hetnet.Edge at 0x1573e7a20>,
#   <hetio.hetnet.Edge at 0x1573f0780>,
#   <hetio.hetnet.Edge at 0x1573f7470>,
#   <hetio.hetnet.Edge at 0x1573f7d30>,
#   <hetio.hetnet.Edge at 0x1573fe1d0>,
#   <hetio.hetnet.Edge at 0x1573fe2b0>,
#   <hetio.hetnet.Edge at 0x1573fe7f0>,
#   <hetio.hetnet.Edge at 0x1573fee10>,
#   <hetio.hetnet.Edge at 0x157407470>,
#   <hetio.hetnet.Edge at 0x157407cc0>,
#   <hetio.hetnet.Edge at 0x15740fc50>,
#   <hetio.hetnet.Edge at 0x15740ffd0>,
#   <hetio.hetnet.Edge at 0x1574160f0>,
#   <hetio.hetnet.Edge at 0x1574166a0>,
#   <hetio.hetnet.Edge at 0x15741e2b0>,
#   <hetio.hetnet.Edge at 0x15741e400>,
#   ...],
#  <hetio.hetnet.MetaEdge at 0x1f2083208>: [<hetio.hetnet.Edge at 0x15619c160>,
#   <hetio.hetnet.Edge at 0x15619c1d0>,
#   <hetio.hetnet.Edge at 0x15619c390>,
#   <hetio.hetnet.Edge at 0x15619c5c0>,
#   <hetio.hetnet.Edge at 0x15619c940>,
#   <hetio.hetnet.Edge at 0x15619ca90>,
#   <hetio.hetnet.Edge at 0x15619cf60>,
#   <hetio.hetnet.Edge at 0x15619cfd0>,
#   <hetio.hetnet.Edge at 0x1561a6320>,
#   <hetio.hetnet.Edge at 0x1561a6a20>,
#   <hetio.hetnet.Edge at 0x1561a6f60>,
#   <hetio.hetnet.Edge at 0x1561af240>,
#   <hetio.hetnet.Edge at 0x1561af2b0>,
#   <hetio.hetnet.Edge at 0x1561af390>,
#   <hetio.hetnet.Edge at 0x1561af470>,
#   <hetio.hetnet.Edge at 0x1561af7f0>,
#   <hetio.hetnet.Edge at 0x1561afbe0>,
#   <hetio.hetnet.Edge at 0x1561afe80>,
#   <hetio.hetnet.Edge at 0x1561b60f0>,
#   <hetio.hetnet.Edge at 0x1561b64e0>,
#   <hetio.hetnet.Edge at 0x1561b6d30>,
#   <hetio.hetnet.Edge at 0x1561b6e80>,
#   <hetio.hetnet.Edge at 0x1561b6f60>,
#   <hetio.hetnet.Edge at 0x1561b6fd0>,
#   <hetio.hetnet.Edge at 0x1561bc470>,
#   <hetio.hetnet.Edge at 0x1561bc550>,
#   <hetio.hetnet.Edge at 0x1561bc5c0>,
#   <hetio.hetnet.Edge at 0x1561bc6a0>,
#   <hetio.hetnet.Edge at 0x1561bc7f0>,
#   <hetio.hetnet.Edge at 0x1561bc8d0>,
#   <hetio.hetnet.Edge at 0x1561bc9b0>,
#   <hetio.hetnet.Edge at 0x1561bca90>,
#   <hetio.hetnet.Edge at 0x1561bce80>,
#   <hetio.hetnet.Edge at 0x1561bcf60>,
#   <hetio.hetnet.Edge at 0x1561bcfd0>,
#   <hetio.hetnet.Edge at 0x1561c50f0>,
#   <hetio.hetnet.Edge at 0x1561c51d0>,
#   <hetio.hetnet.Edge at 0x1561c5400>,
#   <hetio.hetnet.Edge at 0x1561c5860>,
#   <hetio.hetnet.Edge at 0x1561c59b0>,
#   <hetio.hetnet.Edge at 0x1561c5e10>,
#   <hetio.hetnet.Edge at 0x1561cc1d0>,
#   <hetio.hetnet.Edge at 0x1561cc4e0>,
#   <hetio.hetnet.Edge at 0x1561cc5c0>,
#   <hetio.hetnet.Edge at 0x1561cc8d0>,
#   <hetio.hetnet.Edge at 0x1561ccbe0>,
#   <hetio.hetnet.Edge at 0x1561d3630>,
#   <hetio.hetnet.Edge at 0x1561d37f0>,
#   <hetio.hetnet.Edge at 0x1561d3940>,
#   <hetio.hetnet.Edge at 0x1561d3a20>,
#   <hetio.hetnet.Edge at 0x1561d3b00>,
#   <hetio.hetnet.Edge at 0x1561d3d30>,
#   <hetio.hetnet.Edge at 0x1561d3e80>,
#   <hetio.hetnet.Edge at 0x1561d3fd0>,
#   <hetio.hetnet.Edge at 0x1561da0f0>,
#   <hetio.hetnet.Edge at 0x1561da240>,
#   <hetio.hetnet.Edge at 0x1561da2b0>,
#   <hetio.hetnet.Edge at 0x1561da320>,
#   <hetio.hetnet.Edge at 0x1561da390>,
#   <hetio.hetnet.Edge at 0x1561da4e0>,
#   <hetio.hetnet.Edge at 0x1561da550>,
#   <hetio.hetnet.Edge at 0x1561da780>,
#   <hetio.hetnet.Edge at 0x1561da860>,
#   <hetio.hetnet.Edge at 0x1561da8d0>,
#   <hetio.hetnet.Edge at 0x1561da940>,
#   <hetio.hetnet.Edge at 0x1561dae10>,
#   <hetio.hetnet.Edge at 0x1561e31d0>,
#   <hetio.hetnet.Edge at 0x1561e3320>,
#   <hetio.hetnet.Edge at 0x1561e3550>,
#   <hetio.hetnet.Edge at 0x1561e3710>,
#   <hetio.hetnet.Edge at 0x1561e3cc0>,
#   <hetio.hetnet.Edge at 0x1561ea2b0>,
#   <hetio.hetnet.Edge at 0x1561ea4e0>,
#   <hetio.hetnet.Edge at 0x1561ea550>,
#   <hetio.hetnet.Edge at 0x1561ea780>,
#   <hetio.hetnet.Edge at 0x1561ea940>,
#   <hetio.hetnet.Edge at 0x1561eaa20>,
#   <hetio.hetnet.Edge at 0x1561eac50>,
#   <hetio.hetnet.Edge at 0x1561ead30>,
#   <hetio.hetnet.Edge at 0x1561eaf60>,
#   <hetio.hetnet.Edge at 0x1561f1320>,
#   <hetio.hetnet.Edge at 0x1561f1390>,
#   <hetio.hetnet.Edge at 0x1561f14e0>,
#   <hetio.hetnet.Edge at 0x1561f1710>,
#   <hetio.hetnet.Edge at 0x1561f17f0>,
#   <hetio.hetnet.Edge at 0x1561f1b00>,
#   <hetio.hetnet.Edge at 0x1561f1be0>,
#   <hetio.hetnet.Edge at 0x1561f1fd0>,
#   <hetio.hetnet.Edge at 0x1561f90f0>,
#   <hetio.hetnet.Edge at 0x1561f9400>,
#   <hetio.hetnet.Edge at 0x1561f9630>,
#   <hetio.hetnet.Edge at 0x1561f97f0>,
#   <hetio.hetnet.Edge at 0x1561f9b00>,
#   <hetio.hetnet.Edge at 0x1561f9fd0>,
#   <hetio.hetnet.Edge at 0x156200550>,
#   <hetio.hetnet.Edge at 0x156200860>,
#   <hetio.hetnet.Edge at 0x156200a20>,
#   <hetio.hetnet.Edge at 0x156200b00>,
#   <hetio.hetnet.Edge at 0x156200c50>,
#   <hetio.hetnet.Edge at 0x156200d30>,
#   <hetio.hetnet.Edge at 0x156200e80>,
#   <hetio.hetnet.Edge at 0x156207860>,
#   <hetio.hetnet.Edge at 0x156207940>,
#   <hetio.hetnet.Edge at 0x156207be0>,
#   <hetio.hetnet.Edge at 0x156207cc0>,
#   <hetio.hetnet.Edge at 0x156207d30>,
#   <hetio.hetnet.Edge at 0x156207e80>,
#   <hetio.hetnet.Edge at 0x15620e0f0>,
#   <hetio.hetnet.Edge at 0x15620e320>,
#   <hetio.hetnet.Edge at 0x15620e8d0>,
#   <hetio.hetnet.Edge at 0x15620e9b0>,
#   <hetio.hetnet.Edge at 0x15620ea90>,
#   <hetio.hetnet.Edge at 0x15620eb00>,
#   <hetio.hetnet.Edge at 0x15620eda0>,
#   <hetio.hetnet.Edge at 0x15620eef0>,
#   <hetio.hetnet.Edge at 0x1562171d0>,
#   <hetio.hetnet.Edge at 0x156217240>,
#   <hetio.hetnet.Edge at 0x156217550>,
#   <hetio.hetnet.Edge at 0x1562177f0>,
#   <hetio.hetnet.Edge at 0x156217940>,
#   <hetio.hetnet.Edge at 0x156217b00>,
#   <hetio.hetnet.Edge at 0x156217d30>,
#   <hetio.hetnet.Edge at 0x156217ef0>,
#   <hetio.hetnet.Edge at 0x15621e0f0>,
#   <hetio.hetnet.Edge at 0x15621ea90>,
#   <hetio.hetnet.Edge at 0x15621efd0>,
#   <hetio.hetnet.Edge at 0x1562251d0>,
#   <hetio.hetnet.Edge at 0x156225240>,
#   <hetio.hetnet.Edge at 0x156225390>,
#   <hetio.hetnet.Edge at 0x156225400>,
#   <hetio.hetnet.Edge at 0x156225470>,
#   <hetio.hetnet.Edge at 0x156225630>,
#   <hetio.hetnet.Edge at 0x156225a20>,
#   <hetio.hetnet.Edge at 0x156225b00>,
#   <hetio.hetnet.Edge at 0x156225fd0>,
#   <hetio.hetnet.Edge at 0x15622e240>,
#   <hetio.hetnet.Edge at 0x15622e2b0>,
#   <hetio.hetnet.Edge at 0x15622e390>,
#   <hetio.hetnet.Edge at 0x15622e630>,
#   <hetio.hetnet.Edge at 0x15622ea20>,
#   <hetio.hetnet.Edge at 0x15622ee80>,
#   <hetio.hetnet.Edge at 0x1562341d0>,
#   <hetio.hetnet.Edge at 0x156234400>,
#   <hetio.hetnet.Edge at 0x1562345c0>,
#   <hetio.hetnet.Edge at 0x156234710>,
#   <hetio.hetnet.Edge at 0x156234780>,
#   <hetio.hetnet.Edge at 0x1562348d0>,
#   <hetio.hetnet.Edge at 0x156234be0>,
#   <hetio.hetnet.Edge at 0x156234e10>,
#   <hetio.hetnet.Edge at 0x156234e80>,
#   <hetio.hetnet.Edge at 0x156234ef0>,
#   <hetio.hetnet.Edge at 0x15623c160>,
#   <hetio.hetnet.Edge at 0x15623c320>,
#   <hetio.hetnet.Edge at 0x15623c5c0>,
#   <hetio.hetnet.Edge at 0x15623c780>,
#   <hetio.hetnet.Edge at 0x156243080>,
#   <hetio.hetnet.Edge at 0x156243160>,
#   <hetio.hetnet.Edge at 0x156243630>,
#   <hetio.hetnet.Edge at 0x156243710>,
#   <hetio.hetnet.Edge at 0x156243780>,
#   <hetio.hetnet.Edge at 0x156243a90>,
#   <hetio.hetnet.Edge at 0x156243e80>,
#   <hetio.hetnet.Edge at 0x156243ef0>,
#   <hetio.hetnet.Edge at 0x156243f60>,
#   <hetio.hetnet.Edge at 0x156243fd0>,
#   <hetio.hetnet.Edge at 0x15624c4e0>,
#   <hetio.hetnet.Edge at 0x15624c710>,
#   <hetio.hetnet.Edge at 0x15624c9b0>,
#   <hetio.hetnet.Edge at 0x15624ca90>,
#   <hetio.hetnet.Edge at 0x15624cef0>,
#   <hetio.hetnet.Edge at 0x156253080>,
#   <hetio.hetnet.Edge at 0x1562532b0>,
#   <hetio.hetnet.Edge at 0x156253390>,
#   <hetio.hetnet.Edge at 0x156253470>,
#   <hetio.hetnet.Edge at 0x1562536a0>,
#   <hetio.hetnet.Edge at 0x156253710>,
#   <hetio.hetnet.Edge at 0x1562538d0>,
#   <hetio.hetnet.Edge at 0x156253a90>,
#   <hetio.hetnet.Edge at 0x156253b70>,
#   <hetio.hetnet.Edge at 0x156253da0>,
#   <hetio.hetnet.Edge at 0x156253ef0>,
#   <hetio.hetnet.Edge at 0x15625b080>,
#   <hetio.hetnet.Edge at 0x15625b4e0>,
#   <hetio.hetnet.Edge at 0x15625b630>,
#   <hetio.hetnet.Edge at 0x15625bd30>,
#   <hetio.hetnet.Edge at 0x15625bda0>,
#   <hetio.hetnet.Edge at 0x15625be10>,
#   <hetio.hetnet.Edge at 0x15625bfd0>,
#   <hetio.hetnet.Edge at 0x1562641d0>,
#   <hetio.hetnet.Edge at 0x1562642b0>,
#   <hetio.hetnet.Edge at 0x156264390>,
#   <hetio.hetnet.Edge at 0x1562646a0>,
#   <hetio.hetnet.Edge at 0x156264d30>,
#   <hetio.hetnet.Edge at 0x156264da0>,
#   <hetio.hetnet.Edge at 0x156264ef0>,
#   <hetio.hetnet.Edge at 0x15626b160>,
#   <hetio.hetnet.Edge at 0x15626b390>,
#   <hetio.hetnet.Edge at 0x15626b470>,
#   <hetio.hetnet.Edge at 0x15626b4e0>,
#   <hetio.hetnet.Edge at 0x15626b630>,
#   <hetio.hetnet.Edge at 0x15626b860>,
#   <hetio.hetnet.Edge at 0x15626b8d0>,
#   <hetio.hetnet.Edge at 0x15626ba20>,
#   <hetio.hetnet.Edge at 0x15626bc50>,
#   <hetio.hetnet.Edge at 0x15626bef0>,
#   <hetio.hetnet.Edge at 0x1562720f0>,
#   <hetio.hetnet.Edge at 0x156272240>,
#   <hetio.hetnet.Edge at 0x156272550>,
#   <hetio.hetnet.Edge at 0x156272710>,
#   <hetio.hetnet.Edge at 0x1562727f0>,
#   <hetio.hetnet.Edge at 0x156272940>,
#   <hetio.hetnet.Edge at 0x156272e10>,
#   <hetio.hetnet.Edge at 0x156278080>,
#   <hetio.hetnet.Edge at 0x156278160>,
#   <hetio.hetnet.Edge at 0x156278550>,
#   <hetio.hetnet.Edge at 0x1562786a0>,
#   <hetio.hetnet.Edge at 0x156278710>,
#   <hetio.hetnet.Edge at 0x1562788d0>,
#   <hetio.hetnet.Edge at 0x1562789b0>,
#   <hetio.hetnet.Edge at 0x156278a90>,
#   <hetio.hetnet.Edge at 0x156278be0>,
#   <hetio.hetnet.Edge at 0x156278e80>,
#   <hetio.hetnet.Edge at 0x156282080>,
#   <hetio.hetnet.Edge at 0x1562826a0>,
#   <hetio.hetnet.Edge at 0x156282710>,
#   <hetio.hetnet.Edge at 0x1562828d0>,
#   <hetio.hetnet.Edge at 0x156282c50>,
#   <hetio.hetnet.Edge at 0x156282cc0>,
#   <hetio.hetnet.Edge at 0x156282e10>,
#   <hetio.hetnet.Edge at 0x156282ef0>,
#   <hetio.hetnet.Edge at 0x156289160>,
#   <hetio.hetnet.Edge at 0x156289550>,
#   <hetio.hetnet.Edge at 0x1562895c0>,
#   <hetio.hetnet.Edge at 0x156289860>,
#   <hetio.hetnet.Edge at 0x1562898d0>,
#   <hetio.hetnet.Edge at 0x156289f60>,
#   <hetio.hetnet.Edge at 0x156290f60>,
#   <hetio.hetnet.Edge at 0x156290fd0>,
#   <hetio.hetnet.Edge at 0x156299080>,
#   <hetio.hetnet.Edge at 0x1562995c0>,
#   <hetio.hetnet.Edge at 0x156299860>,
#   <hetio.hetnet.Edge at 0x156299ef0>,
#   <hetio.hetnet.Edge at 0x1562a00f0>,
#   <hetio.hetnet.Edge at 0x1562a0240>,
#   <hetio.hetnet.Edge at 0x1562a0550>,
#   <hetio.hetnet.Edge at 0x1562a07f0>,
#   <hetio.hetnet.Edge at 0x1562a0a90>,
#   <hetio.hetnet.Edge at 0x1562a0da0>,
#   <hetio.hetnet.Edge at 0x1562a0e80>,
#   <hetio.hetnet.Edge at 0x1562a0ef0>,
#   <hetio.hetnet.Edge at 0x1562a0f60>,
#   <hetio.hetnet.Edge at 0x1562a7320>,
#   <hetio.hetnet.Edge at 0x1562a75c0>,
#   <hetio.hetnet.Edge at 0x1562a7860>,
#   <hetio.hetnet.Edge at 0x1562a7940>,
#   <hetio.hetnet.Edge at 0x1562a7a90>,
#   <hetio.hetnet.Edge at 0x1562a7b70>,
#   <hetio.hetnet.Edge at 0x1562a7ef0>,
#   <hetio.hetnet.Edge at 0x1562ae240>,
#   <hetio.hetnet.Edge at 0x1562ae4e0>,
# ...
#   <hetio.hetnet.Edge at 0x2164c6be0>,
#   <hetio.hetnet.Edge at 0x21664f860>,
#   <hetio.hetnet.Edge at 0x2167577f0>,
#   <hetio.hetnet.Edge at 0x2168ef550>,
#   <hetio.hetnet.Edge at 0x2169868d0>,
#   <hetio.hetnet.Edge at 0x216aea630>,
#   <hetio.hetnet.Edge at 0x216c082b0>,
#   <hetio.hetnet.Edge at 0x216c79630>,
#   <hetio.hetnet.Edge at 0x216daef60>,
#   <hetio.hetnet.Edge at 0x216e71e80>,
#   <hetio.hetnet.Edge at 0x216f37860>,
#   <hetio.hetnet.Edge at 0x2170ad320>,
#   <hetio.hetnet.Edge at 0x21711ea20>,
#   <hetio.hetnet.Edge at 0x217265160>,
#   <hetio.hetnet.Edge at 0x2175e21d0>,
#   <hetio.hetnet.Edge at 0x217610fd0>,
#   <hetio.hetnet.Edge at 0x21763f780>,
#   <hetio.hetnet.Edge at 0x217884b00>,
#   <hetio.hetnet.Edge at 0x217942d30>,
#   <hetio.hetnet.Edge at 0x217c7bd30>,
#   <hetio.hetnet.Edge at 0x217fff400>,
#   <hetio.hetnet.Edge at 0x2182dee80>,
#   <hetio.hetnet.Edge at 0x218340f60>,
#   <hetio.hetnet.Edge at 0x21835dcc0>,
#   <hetio.hetnet.Edge at 0x2183ed7f0>,
#   <hetio.hetnet.Edge at 0x21849bef0>,
#   <hetio.hetnet.Edge at 0x2187ced30>,
#   <hetio.hetnet.Edge at 0x218820a90>,
#   <hetio.hetnet.Edge at 0x21886cd30>,
#   <hetio.hetnet.Edge at 0x218a0a400>,
#   <hetio.hetnet.Edge at 0x218d07400>,
#   <hetio.hetnet.Edge at 0x218da0da0>,
#   <hetio.hetnet.Edge at 0x218eeeb70>,
#   <hetio.hetnet.Edge at 0x218f2bd30>,
#   <hetio.hetnet.Edge at 0x218fd1080>,
#   <hetio.hetnet.Edge at 0x219069550>,
#   <hetio.hetnet.Edge at 0x2192445c0>,
#   <hetio.hetnet.Edge at 0x21933e470>,
#   <hetio.hetnet.Edge at 0x2194502b0>,
#   <hetio.hetnet.Edge at 0x2197dd470>,
#   <hetio.hetnet.Edge at 0x21986be10>,
#   <hetio.hetnet.Edge at 0x21991bbe0>,
#   <hetio.hetnet.Edge at 0x219f6d080>,
#   <hetio.hetnet.Edge at 0x21a22b9b0>,
#   <hetio.hetnet.Edge at 0x21a35e8d0>,
#   <hetio.hetnet.Edge at 0x21a442320>,
#   <hetio.hetnet.Edge at 0x21a5266a0>,
#   <hetio.hetnet.Edge at 0x21a5ff240>,
#   <hetio.hetnet.Edge at 0x21a7c5470>,
#   <hetio.hetnet.Edge at 0x21aa477f0>,
#   <hetio.hetnet.Edge at 0x21aaf40f0>,
#   <hetio.hetnet.Edge at 0x21ab517f0>,
#   <hetio.hetnet.Edge at 0x21ad2ca20>,
#   <hetio.hetnet.Edge at 0x21ad8e390>,
#   <hetio.hetnet.Edge at 0x21b38b4e0>,
#   <hetio.hetnet.Edge at 0x21b3b81d0>,
#   <hetio.hetnet.Edge at 0x21b599c50>,
#   <hetio.hetnet.Edge at 0x21bb2a2b0>,
#   <hetio.hetnet.Edge at 0x21bc0f470>,
#   <hetio.hetnet.Edge at 0x21bcef9b0>,
#   <hetio.hetnet.Edge at 0x21bdb46a0>,
#   <hetio.hetnet.Edge at 0x21bfdbda0>,
#   <hetio.hetnet.Edge at 0x21c06b400>,
#   <hetio.hetnet.Edge at 0x21c07ad30>,
#   <hetio.hetnet.Edge at 0x21c31bb70>,
#   <hetio.hetnet.Edge at 0x21c6f0860>,
#   <hetio.hetnet.Edge at 0x21ca27400>,
#   <hetio.hetnet.Edge at 0x21cb9ae10>,
#   <hetio.hetnet.Edge at 0x21ccfe5c0>,
#   <hetio.hetnet.Edge at 0x21cef9b70>,
#   <hetio.hetnet.Edge at 0x21cf44ef0>,
#   <hetio.hetnet.Edge at 0x21cf7f550>,
#   <hetio.hetnet.Edge at 0x21d0be550>,
#   <hetio.hetnet.Edge at 0x21d27f4e0>,
#   <hetio.hetnet.Edge at 0x21d2c9b00>,
#   <hetio.hetnet.Edge at 0x21d2df7f0>,
#   <hetio.hetnet.Edge at 0x21d79d780>,
#   <hetio.hetnet.Edge at 0x21d8974e0>,
#   <hetio.hetnet.Edge at 0x21da5f780>,
#   <hetio.hetnet.Edge at 0x21dad7240>,
#   <hetio.hetnet.Edge at 0x21def8cc0>,
#   <hetio.hetnet.Edge at 0x21df171d0>,
#   <hetio.hetnet.Edge at 0x228511a20>,
#   <hetio.hetnet.Edge at 0x228545ef0>,
#   <hetio.hetnet.Edge at 0x2286b9e10>,
#   <hetio.hetnet.Edge at 0x2289615c0>,
#   <hetio.hetnet.Edge at 0x228b0a1d0>,
#   <hetio.hetnet.Edge at 0x228ddfa90>,
#   <hetio.hetnet.Edge at 0x229133ef0>,
#   <hetio.hetnet.Edge at 0x22914a390>,
#   <hetio.hetnet.Edge at 0x22935df60>,
#   <hetio.hetnet.Edge at 0x2295694e0>,
#   <hetio.hetnet.Edge at 0x229598be0>,
#   <hetio.hetnet.Edge at 0x229617be0>,
#   <hetio.hetnet.Edge at 0x22994bf60>,
#   <hetio.hetnet.Edge at 0x22998e4e0>,
#   <hetio.hetnet.Edge at 0x229acc080>,
#   <hetio.hetnet.Edge at 0x229ae3940>,
#   <hetio.hetnet.Edge at 0x229b461d0>,
#   <hetio.hetnet.Edge at 0x229c99ef0>,
#   <hetio.hetnet.Edge at 0x229db1400>,
#   <hetio.hetnet.Edge at 0x229e86a90>,
#   <hetio.hetnet.Edge at 0x229f69a90>,
#   <hetio.hetnet.Edge at 0x229fbd7f0>,
#   <hetio.hetnet.Edge at 0x22a0100f0>,
#   <hetio.hetnet.Edge at 0x22a037860>,
#   <hetio.hetnet.Edge at 0x22a05b240>,
#   <hetio.hetnet.Edge at 0x22a181320>,
#   <hetio.hetnet.Edge at 0x22a1e3a20>,
#   <hetio.hetnet.Edge at 0x22a273b00>,
#   <hetio.hetnet.Edge at 0x22a6afa90>,
#   <hetio.hetnet.Edge at 0x22aec96a0>,
#   <hetio.hetnet.Edge at 0x22aff6160>,
#   <hetio.hetnet.Edge at 0x22b0421d0>,
#   <hetio.hetnet.Edge at 0x22b2c28d0>,
#   <hetio.hetnet.Edge at 0x22b3f37f0>,
#   <hetio.hetnet.Edge at 0x22b3f9470>,
#   <hetio.hetnet.Edge at 0x22b409940>,
#   <hetio.hetnet.Edge at 0x22b4ce5c0>,
#   <hetio.hetnet.Edge at 0x22b4fbda0>,
#   <hetio.hetnet.Edge at 0x22b537320>,
#   <hetio.hetnet.Edge at 0x22b73ada0>,
#   <hetio.hetnet.Edge at 0x22b810be0>,
#   <hetio.hetnet.Edge at 0x22b818630>,
#   <hetio.hetnet.Edge at 0x22b8dca20>,
#   <hetio.hetnet.Edge at 0x22b956c50>,
#   <hetio.hetnet.Edge at 0x22bb204e0>,
#   <hetio.hetnet.Edge at 0x22bcc9e10>,
#   <hetio.hetnet.Edge at 0x22bd150f0>,
#   <hetio.hetnet.Edge at 0x22c2e2a20>,
#   <hetio.hetnet.Edge at 0x22c335ef0>,
#   <hetio.hetnet.Edge at 0x22c379470>,
#   <hetio.hetnet.Edge at 0x22cb59470>,
#   <hetio.hetnet.Edge at 0x22cca2240>,
#   <hetio.hetnet.Edge at 0x22cd7e0f0>,
#   <hetio.hetnet.Edge at 0x22cff5630>,
#   <hetio.hetnet.Edge at 0x22d0f0400>,
#   <hetio.hetnet.Edge at 0x22d225b70>,
#   <hetio.hetnet.Edge at 0x22d26a0f0>,
#   <hetio.hetnet.Edge at 0x22d2eb1d0>,
#   <hetio.hetnet.Edge at 0x22d4eb470>,
#   <hetio.hetnet.Edge at 0x22d67b780>,
#   <hetio.hetnet.Edge at 0x22e55f6a0>,
#   <hetio.hetnet.Edge at 0x22e648e80>,
#   <hetio.hetnet.Edge at 0x22e6c8f60>,
#   <hetio.hetnet.Edge at 0x22e879e10>,
#   <hetio.hetnet.Edge at 0x22ef9dfd0>,
#   <hetio.hetnet.Edge at 0x22f000240>,
#   <hetio.hetnet.Edge at 0x22f109be0>,
#   <hetio.hetnet.Edge at 0x22f4116a0>,
#   <hetio.hetnet.Edge at 0x22f4cf9b0>,
#   <hetio.hetnet.Edge at 0x22f4de4e0>,
#   <hetio.hetnet.Edge at 0x22f7e0470>,
#   <hetio.hetnet.Edge at 0x22f860390>,
#   <hetio.hetnet.Edge at 0x22f9bc630>,
#   <hetio.hetnet.Edge at 0x22fa437f0>,
#   <hetio.hetnet.Edge at 0x22fabcda0>,
#   <hetio.hetnet.Edge at 0x22fe09240>,
#   <hetio.hetnet.Edge at 0x22ffa7390>,
#   <hetio.hetnet.Edge at 0x2304db4e0>,
#   <hetio.hetnet.Edge at 0x230712ef0>,
#   <hetio.hetnet.Edge at 0x230ca3e10>,
#   <hetio.hetnet.Edge at 0x230d5ffd0>,
#   <hetio.hetnet.Edge at 0x230d95860>,
#   <hetio.hetnet.Edge at 0x230e851d0>,
#   <hetio.hetnet.Edge at 0x230fc2550>,
#   <hetio.hetnet.Edge at 0x2312de4e0>,
#   <hetio.hetnet.Edge at 0x2315f94e0>,
#   <hetio.hetnet.Edge at 0x231c248d0>,
#   <hetio.hetnet.Edge at 0x231df8d30>,
#   <hetio.hetnet.Edge at 0x231e1c2b0>,
#   <hetio.hetnet.Edge at 0x231e51d30>,
#   <hetio.hetnet.Edge at 0x232321710>,
#   <hetio.hetnet.Edge at 0x232560780>,
#   <hetio.hetnet.Edge at 0x2328ec710>,
#   <hetio.hetnet.Edge at 0x232a218d0>,
#   <hetio.hetnet.Edge at 0x232c14390>,
#   <hetio.hetnet.Edge at 0x232d60a20>,
#   <hetio.hetnet.Edge at 0x2330afbe0>,
#   <hetio.hetnet.Edge at 0x2330bf710>,
#   <hetio.hetnet.Edge at 0x23318ce10>,
#   <hetio.hetnet.Edge at 0x2332b0fd0>,
#   <hetio.hetnet.Edge at 0x233575da0>,
#   <hetio.hetnet.Edge at 0x23363e8d0>,
#   <hetio.hetnet.Edge at 0x2336bf390>,
#   <hetio.hetnet.Edge at 0x2341da470>,
#   <hetio.hetnet.Edge at 0x234955240>,
#   <hetio.hetnet.Edge at 0x2349be940>,
#   <hetio.hetnet.Edge at 0x2349dd320>,
#   <hetio.hetnet.Edge at 0x234b49ef0>,
#   <hetio.hetnet.Edge at 0x234c060f0>,
#   <hetio.hetnet.Edge at 0x234e968d0>,
#   <hetio.hetnet.Edge at 0x235001240>,
#   <hetio.hetnet.Edge at 0x2350b7940>,
#   <hetio.hetnet.Edge at 0x2353a7ef0>,
#   <hetio.hetnet.Edge at 0x23546c8d0>,
#   <hetio.hetnet.Edge at 0x235544940>,
#   <hetio.hetnet.Edge at 0x2355b0e80>,
#   <hetio.hetnet.Edge at 0x2358b9b70>,
#   <hetio.hetnet.Edge at 0x235bc7fd0>,
#   <hetio.hetnet.Edge at 0x120a89a90>,
#   <hetio.hetnet.Edge at 0x236314710>,
#   <hetio.hetnet.Edge at 0x23653c6a0>,
#   <hetio.hetnet.Edge at 0x2365b6630>,
#   <hetio.hetnet.Edge at 0x236822160>,
#   <hetio.hetnet.Edge at 0x236b34b00>,
#   <hetio.hetnet.Edge at 0x236da8c50>,
#   <hetio.hetnet.Edge at 0x237636f60>,
#   <hetio.hetnet.Edge at 0x2376e48d0>,
#   <hetio.hetnet.Edge at 0x237cd3550>,
#   <hetio.hetnet.Edge at 0x237d905c0>,
#   <hetio.hetnet.Edge at 0x238070e10>,
#   <hetio.hetnet.Edge at 0x2382971d0>,
#   <hetio.hetnet.Edge at 0x2385ec9b0>,
#   <hetio.hetnet.Edge at 0x23898e390>,
#   <hetio.hetnet.Edge at 0x238d26be0>,
#   <hetio.hetnet.Edge at 0x238e27470>,
#   <hetio.hetnet.Edge at 0x23941f080>,
#   <hetio.hetnet.Edge at 0x23952e160>,
#   <hetio.hetnet.Edge at 0x23961eda0>,
#   <hetio.hetnet.Edge at 0x2397ff1d0>,
#   <hetio.hetnet.Edge at 0x2399f7be0>,
#   <hetio.hetnet.Edge at 0x239fa1da0>,
#   <hetio.hetnet.Edge at 0x23a04ec50>,
#   <hetio.hetnet.Edge at 0x23a0b7ef0>,
#   <hetio.hetnet.Edge at 0x23ab26160>,
#   <hetio.hetnet.Edge at 0x23ac011d0>,
#   <hetio.hetnet.Edge at 0x23ac4c550>,
#   <hetio.hetnet.Edge at 0x23adae320>,
#   <hetio.hetnet.Edge at 0x23ae27a20>,
#   <hetio.hetnet.Edge at 0x23b1ccda0>,
#   <hetio.hetnet.Edge at 0x23b318320>,
#   <hetio.hetnet.Edge at 0x23b565b70>,
#   <hetio.hetnet.Edge at 0x23b691320>,
#   <hetio.hetnet.Edge at 0x23b81f940>,
#   <hetio.hetnet.Edge at 0x23b8376a0>,
#   <hetio.hetnet.Edge at 0x23b86b860>,
#   <hetio.hetnet.Edge at 0x23b946710>,
#   <hetio.hetnet.Edge at 0x23bb0f940>,
#   <hetio.hetnet.Edge at 0x23bbe32b0>,
#   <hetio.hetnet.Edge at 0x23c069240>,
#   <hetio.hetnet.Edge at 0x23c086b70>,
#   <hetio.hetnet.Edge at 0x23c15f390>,
#   <hetio.hetnet.Edge at 0x23c26e550>,
#   <hetio.hetnet.Edge at 0x23c4f67f0>,
#   <hetio.hetnet.Edge at 0x23c678710>,
#   <hetio.hetnet.Edge at 0x23cab5fd0>,
#   <hetio.hetnet.Edge at 0x23cc1fcc0>,
#   <hetio.hetnet.Edge at 0x23cf71f60>,
#   <hetio.hetnet.Edge at 0x23d35b400>,
#   <hetio.hetnet.Edge at 0x23d4bcc50>,
#   <hetio.hetnet.Edge at 0x23d9612b0>,
#   <hetio.hetnet.Edge at 0x23db7e7f0>,
#   <hetio.hetnet.Edge at 0x23dcc2da0>,
#   <hetio.hetnet.Edge at 0x23ddaa390>,
#   <hetio.hetnet.Edge at 0x23e02a710>,
#   <hetio.hetnet.Edge at 0x23e0a2240>,
#   <hetio.hetnet.Edge at 0x23e1136a0>,
#   <hetio.hetnet.Edge at 0x23e184320>,
#   <hetio.hetnet.Edge at 0x23e41ef60>,
#   <hetio.hetnet.Edge at 0x23e600ef0>,
#   <hetio.hetnet.Edge at 0x23e854160>,
#   <hetio.hetnet.Edge at 0x23e9e95c0>,
#   <hetio.hetnet.Edge at 0x23ea07f60>,
#   <hetio.hetnet.Edge at 0x23ec30fd0>,
#   <hetio.hetnet.Edge at 0x23ecf6b00>,
#   <hetio.hetnet.Edge at 0x23ed32710>,
#   <hetio.hetnet.Edge at 0x23ed85860>,
#   <hetio.hetnet.Edge at 0x23ee9dfd0>,
#   <hetio.hetnet.Edge at 0x23eebc780>,
#   <hetio.hetnet.Edge at 0x23ef8fa20>,
#   <hetio.hetnet.Edge at 0x23efbd710>,
#   <hetio.hetnet.Edge at 0x23f296630>,
#   <hetio.hetnet.Edge at 0x23f2d3160>,
#   <hetio.hetnet.Edge at 0x23f2ff4e0>,
#   <hetio.hetnet.Edge at 0x23f471400>,
#   <hetio.hetnet.Edge at 0x23f71e6a0>,
#   <hetio.hetnet.Edge at 0x23fc9f320>,
#   <hetio.hetnet.Edge at 0x23fdfb2b0>,
#   <hetio.hetnet.Edge at 0x23fe36e80>,
#   <hetio.hetnet.Edge at 0x23ff21cc0>,
#   <hetio.hetnet.Edge at 0x24001a400>,
#   <hetio.hetnet.Edge at 0x24011a0f0>,
#   <hetio.hetnet.Edge at 0x2402ce240>,
#   <hetio.hetnet.Edge at 0x240566f60>,
#   <hetio.hetnet.Edge at 0x2407e4f60>,
#   <hetio.hetnet.Edge at 0x2409579b0>,
#   <hetio.hetnet.Edge at 0x2409e8c50>,
#   <hetio.hetnet.Edge at 0x240a24da0>,
#   <hetio.hetnet.Edge at 0x240bfda20>,
#   <hetio.hetnet.Edge at 0x240c21fd0>,
#   <hetio.hetnet.Edge at 0x240c82860>,
#   <hetio.hetnet.Edge at 0x240da96a0>,
#   <hetio.hetnet.Edge at 0x240fa9e10>,
#   <hetio.hetnet.Edge at 0x240faf470>,
#   <hetio.hetnet.Edge at 0x240fc0e10>,
#   <hetio.hetnet.Edge at 0x2412a2080>,
#   <hetio.hetnet.Edge at 0x241321be0>,
#   <hetio.hetnet.Edge at 0x241439940>,
#   <hetio.hetnet.Edge at 0x2414fea20>,
#   <hetio.hetnet.Edge at 0x241742b70>,
#   <hetio.hetnet.Edge at 0x241795390>,
#   <hetio.hetnet.Edge at 0x2418bdf60>,
#   <hetio.hetnet.Edge at 0x241b7a4e0>,
#   <hetio.hetnet.Edge at 0x242363b70>,
#   <hetio.hetnet.Edge at 0x24247a940>,
#   <hetio.hetnet.Edge at 0x2424a8780>,
#   <hetio.hetnet.Edge at 0x2425c6630>,
#   <hetio.hetnet.Edge at 0x242a07ef0>,
#   <hetio.hetnet.Edge at 0x242cffbe0>,
#   <hetio.hetnet.Edge at 0x242d90a20>,
#   <hetio.hetnet.Edge at 0x242e16ef0>,
#   <hetio.hetnet.Edge at 0x243053630>,
#   <hetio.hetnet.Edge at 0x243e3ea20>,
#   <hetio.hetnet.Edge at 0x243e82080>,
#   <hetio.hetnet.Edge at 0x243eebd30>,
#   <hetio.hetnet.Edge at 0x2441278d0>,
#   <hetio.hetnet.Edge at 0x244418160>,
#   <hetio.hetnet.Edge at 0x24442e8d0>,
#   <hetio.hetnet.Edge at 0x2444f0da0>,
#   <hetio.hetnet.Edge at 0x24468d9b0>,
#   <hetio.hetnet.Edge at 0x244ea36a0>,
#   <hetio.hetnet.Edge at 0x2450ca940>,
#   <hetio.hetnet.Edge at 0x245500b00>,
#   <hetio.hetnet.Edge at 0x2458f16a0>,
#   <hetio.hetnet.Edge at 0x245bd0240>,
#   <hetio.hetnet.Edge at 0x245e93390>,
#   <hetio.hetnet.Edge at 0x246362d30>,
#   <hetio.hetnet.Edge at 0x24669f5c0>,
#   <hetio.hetnet.Edge at 0x2466f1470>,
#   <hetio.hetnet.Edge at 0x2471c0940>,
#   <hetio.hetnet.Edge at 0x24725eda0>,
#   <hetio.hetnet.Edge at 0x2472c0940>,
#   <hetio.hetnet.Edge at 0x2474aaa20>,
#   <hetio.hetnet.Edge at 0x247757e80>,
#   <hetio.hetnet.Edge at 0x247acc0f0>,
#   <hetio.hetnet.Edge at 0x247bd36a0>,
#   <hetio.hetnet.Edge at 0x247caee80>,
#   <hetio.hetnet.Edge at 0x247deb0f0>,
#   <hetio.hetnet.Edge at 0x247f611d0>,
#   <hetio.hetnet.Edge at 0x247fca6a0>,
#   <hetio.hetnet.Edge at 0x247ff88d0>,
#   <hetio.hetnet.Edge at 0x2480cb240>,
#   <hetio.hetnet.Edge at 0x2482daa90>,
#   <hetio.hetnet.Edge at 0x24859d860>,
#   <hetio.hetnet.Edge at 0x248a0df60>,
#   <hetio.hetnet.Edge at 0x248c9aa90>,
#   <hetio.hetnet.Edge at 0x248cce240>,
#   <hetio.hetnet.Edge at 0x248d19400>,
#   <hetio.hetnet.Edge at 0x248da7a20>,
#   <hetio.hetnet.Edge at 0x248e63160>,
#   <hetio.hetnet.Edge at 0x248ec6710>,
#   <hetio.hetnet.Edge at 0x24916b2b0>,
#   <hetio.hetnet.Edge at 0x249363780>,
#   <hetio.hetnet.Edge at 0x249573390>,
#   <hetio.hetnet.Edge at 0x249630550>,
#   <hetio.hetnet.Edge at 0x249692a90>,
#   <hetio.hetnet.Edge at 0x2496dcfd0>,
#   <hetio.hetnet.Edge at 0x24999a320>,
#   <hetio.hetnet.Edge at 0x249a411d0>,
#   <hetio.hetnet.Edge at 0x249c0a9b0>,
#   <hetio.hetnet.Edge at 0x249fadfd0>,
#   <hetio.hetnet.Edge at 0x24a1e7b00>,
#   <hetio.hetnet.Edge at 0x24a2b3a20>,
#   <hetio.hetnet.Edge at 0x24a60ca90>,
#   <hetio.hetnet.Edge at 0x24a88ca90>,
#   <hetio.hetnet.Edge at 0x24a9f37f0>,
#   <hetio.hetnet.Edge at 0x24ab6da90>,
#   <hetio.hetnet.Edge at 0x24ac89da0>,
#   <hetio.hetnet.Edge at 0x24b0a2780>,
#   <hetio.hetnet.Edge at 0x24b1a9080>,
#   <hetio.hetnet.Edge at 0x24b1a91d0>,
#   <hetio.hetnet.Edge at 0x24b263860>,
#   <hetio.hetnet.Edge at 0x24b3911d0>,
#   <hetio.hetnet.Edge at 0x24b52c780>,
#   <hetio.hetnet.Edge at 0x24b8074e0>,
#   <hetio.hetnet.Edge at 0x24b8fdb70>,
#   <hetio.hetnet.Edge at 0x24b96f940>,
#   <hetio.hetnet.Edge at 0x24bf2c710>,
#   <hetio.hetnet.Edge at 0x24c1ed5c0>,
#   <hetio.hetnet.Edge at 0x24c231a20>,
#   <hetio.hetnet.Edge at 0x24c5160f0>,
#   <hetio.hetnet.Edge at 0x24c74ce10>,
#   <hetio.hetnet.Edge at 0x24c9e1940>,
#   <hetio.hetnet.Edge at 0x24cae1fd0>,
#   <hetio.hetnet.Edge at 0x24cb3a390>,
#   <hetio.hetnet.Edge at 0x24ce42780>,
#   <hetio.hetnet.Edge at 0x24cf7e550>,
#   <hetio.hetnet.Edge at 0x24cf8de10>,
#   <hetio.hetnet.Edge at 0x24d443c50>,
#   <hetio.hetnet.Edge at 0x24d4a3be0>,
#   <hetio.hetnet.Edge at 0x24d6b9b00>,
#   <hetio.hetnet.Edge at 0x24da1fb00>,
#   <hetio.hetnet.Edge at 0x24dd68160>,
#   <hetio.hetnet.Edge at 0x24de8a4e0>,
#   <hetio.hetnet.Edge at 0x24e34bda0>,
#   <hetio.hetnet.Edge at 0x24e502b70>,
#   <hetio.hetnet.Edge at 0x24e717c50>,
#   <hetio.hetnet.Edge at 0x24e9d3d30>,
#   <hetio.hetnet.Edge at 0x24eb061d0>,
#   <hetio.hetnet.Edge at 0x24eb9bfd0>,
#   <hetio.hetnet.Edge at 0x24ecdd390>,
#   <hetio.hetnet.Edge at 0x24ed6da90>,
#   <hetio.hetnet.Edge at 0x24edb2780>,
#   <hetio.hetnet.Edge at 0x24edc0be0>,
#   <hetio.hetnet.Edge at 0x24edd7320>,
#   <hetio.hetnet.Edge at 0x24f1330f0>,
#   <hetio.hetnet.Edge at 0x24f1500f0>,
#   <hetio.hetnet.Edge at 0x24f303940>,
#   <hetio.hetnet.Edge at 0x24f43fef0>,
#   <hetio.hetnet.Edge at 0x24f5add30>,
#   <hetio.hetnet.Edge at 0x24f82e240>,
#   <hetio.hetnet.Edge at 0x24faac630>,
#   <hetio.hetnet.Edge at 0x24fad0320>,
#   <hetio.hetnet.Edge at 0x2500a6a90>,
#   <hetio.hetnet.Edge at 0x2500dc1d0>,
#   <hetio.hetnet.Edge at 0x250103390>,
#   <hetio.hetnet.Edge at 0x2502fa550>,
#   <hetio.hetnet.Edge at 0x2503ae710>,
#   <hetio.hetnet.Edge at 0x250443400>,
#   ...]}

# %%
for meta in possible_metapaths[0:10]:
    print(hetio.pathtools.paths_between(graph=graph, source=subgraph_nodes[0], target=subgraph_nodes[1], 
                                  metapath=meta))
# Out:
# []
# []
# []
# []
# [Gene::10521 - downregulates - Anatomy::UBERON:0002030 - downregulates - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0000997 - downregulates - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0002107 - downregulates - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0002369 - downregulates - Gene::57599]
# [Gene::10521 - downregulates - Anatomy::UBERON:0001013 - expresses - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0002030 - expresses - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0002107 - expresses - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0000955 - expresses - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0000473 - expresses - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0000997 - expresses - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0002369 - expresses - Gene::57599, Gene::10521 - downregulates - Anatomy::UBERON:0001891 - expresses - Gene::57599]
# [Gene::10521 - downregulates - Anatomy::UBERON:0000473 - upregulates - Gene::57599]
# [Gene::10521 - expresses - Anatomy::UBERON:0001044 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001235 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002081 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002030 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000029 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002107 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000997 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002048 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002369 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002185 - downregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002082 - downregulates - Gene::57599]
# [Gene::10521 - expresses - Anatomy::UBERON:0001235 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002030 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001896 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000007 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001225 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002371 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000992 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002048 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002450 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002369 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001295 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000966 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000002 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000178 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002081 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000995 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000043 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002037 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000996 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002107 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000955 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002367 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002349 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000029 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000057 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001231 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002240 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001893 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000948 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001296 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002046 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001911 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000473 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002185 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001891 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001044 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001013 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000006 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001264 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0003126 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000997 - expresses - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001675 - expresses - Gene::57599]
# [Gene::10521 - expresses - Anatomy::UBERON:0000178 - upregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002240 - upregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001296 - upregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0002046 - upregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0000473 - upregulates - Gene::57599, Gene::10521 - expresses - Anatomy::UBERON:0001675 - upregulates - Gene::57599]

# %%
# Specify compound and disease
compound_id = 'Compound', 'DB01156'  # Bupropion
disease_id = 'Disease', 'DOID:0050742'  # nicotine dependences
metapath = metagraph.metapath_from_abbrev('CbGpPWpGaD')

# %%
compound_id
# Out:
# ('Compound', 'DB01156')

# %%
# Extract walks between genes
paths = hetio.pathtools.paths_between(
    graph, 
    source=graph.node_dict[compound_id],
    target=graph.node_dict[disease_id],
    #metapath=metapath,
    duplicates=True,
)

# %%
metaedges = set(metapath)
nodes = set()
for path in paths:
    nodes.update(path.get_nodes())
    for edge in path:
        # Add incidental nodes along paths to enable correct DWWC/DWPC computations
        # for the CbGpPWpGaD metapath
        nodes.update(e.target for e in edge.source.get_edges(edge.metaedge))
        nodes.update(e.target for e in edge.target.get_edges(edge.metaedge.inverse))

# Add Gene-interacts-Gene metaedge (not essential but may be useful)
metaedges.add(metagraph.metapath_from_abbrev('GiG')[0])

# Get subgraph
subgraph = graph.get_subgraph(metaedges=metaedges, nodes=nodes)

# %%
# Metagraph size
subgraph.metagraph.n_nodes, subgraph.metagraph.n_edges
# Out:
# (4, 4)

# %%
# Graph size
subgraph.n_nodes, subgraph.n_edges
# Out:
# (3060, 18474)

# %%
# Metanode info
hetio.stats.get_metanode_df(subgraph)
# Out:
#    metanode abbreviation  metaedges  nodes  unconnected_nodes
# 0  Compound            C          1    730                730
# 3   Disease            D          1     16                 16
# 1      Gene            G          4   2226                612
# 2   Pathway           PW          1     88                  0

# %%
# Metaedge info
hetio.stats.get_metaedge_df(subgraph)
# Out:
#                         metaedge abbreviation  edges  source_nodes  \
# 0        Compound - binds - Gene          CbG   5634           730
# 1    Disease - associates - Gene          DaG    937            16
# 2        Gene - interacts - Gene          GiG   5124          1061
# 3  Gene - participates - Pathway         GpPW   6779          2222
#
#    target_nodes
# 0           472
# 1           557
# 2          1213
# 3            88

# %%
# Export as JSON
hetio.readwrite.write_graph(subgraph, 'bupropion-CbGpPWpGaD-subgraph.json.xz')

# %% [markdown]
# ## Random subgraph of ~100 nodes per metanode
#
# Choose a different number of nodes per metanode to increase the liklihood rotten matrix operations cause misalignment.

# %%
metanode_to_nodes = graph.get_metanode_to_nodes()
n_nodes = 100
node_subset = list()
random.seed(0, version=2)
for metanode, nodes in sorted(metanode_to_nodes.items()):
    nodes = sorted(nodes)
    nodes = random.sample(nodes, n_nodes)
    node_subset.extend(nodes)
    n_nodes += 1

# %%
# Get subgraph
subgraph = graph.get_subgraph(nodes=node_subset)

# %%
# Metagraph size
subgraph.metagraph.n_nodes, subgraph.metagraph.n_edges
# Out:
# (11, 24)

# %%
# Graph size
subgraph.n_nodes, subgraph.n_edges
# Out:
# (1155, 3123)

# %%
# Metanode info
hetio.stats.get_metanode_df(subgraph)
# Out:
#                metanode abbreviation  metaedges  nodes  unconnected_nodes
# 0               Anatomy            A          4    100                  7
# 1    Biological Process           BP          1    101                 86
# 2    Cellular Component           CC          1    102                 90
# 3              Compound            C          8    103                 73
# 4               Disease            D          8    104                 22
# 5                  Gene            G         16    105                 19
# 6    Molecular Function           MF          1    106                 95
# 7               Pathway           PW          1    107                 87
# 8   Pharmacologic Class           PC          1    108                108
# 9           Side Effect           SE          1    109                 76
# 10              Symptom            S          1    110                 14

# %%
# Metaedge info
hetio.stats.get_metaedge_df(subgraph)
# Out:
#                                      metaedge abbreviation  edges  \
# 0              Anatomy - downregulates - Gene          AdG    173
# 1                  Anatomy - expresses - Gene          AeG    735
# 2                Anatomy - upregulates - Gene          AuG    126
# 6                     Compound - binds - Gene          CbG     10
# 9             Compound - causes - Side Effect         CcSE    170
# 7             Compound - downregulates - Gene          CdG      6
# 4              Compound - palliates - Disease          CpD     26
# 3             Compound - resembles - Compound          CrC     16
# 5                 Compound - treats - Disease          CtD     37
# 8               Compound - upregulates - Gene          CuG      4
# 12                Disease - associates - Gene          DaG     62
# 13             Disease - downregulates - Gene          DdG     26
# 10              Disease - localizes - Anatomy          DlA    636
# 15               Disease - presents - Symptom          DpS    631
# 11              Disease - resembles - Disease          DrD    309
# 14               Disease - upregulates - Gene          DuG     28
# 18                     Gene - covaries - Gene          GcG      1
# 19                    Gene - interacts - Gene          GiG      2
# 16   Gene - participates - Biological Process         GpBP     33
# 17   Gene - participates - Cellular Component         GpCC     32
# 21   Gene - participates - Molecular Function         GpMF     13
# 22              Gene - participates - Pathway         GpPW     25
# 20                    Gene > regulates > Gene         Gr>G      3
# 23  Pharmacologic Class - includes - Compound         PCiC     19
#
#     source_nodes  target_nodes
# 0             13            64
# 1             29            80
# 2             13            58
# 6             10             1
# 9             53            33
# 7              6             4
# 4             16            13
# 3             14            14
# 5             18            26
# 8              3             4
# 12            37            24
# 13            18            23
# 10            95            93
# 15            96            96
# 11            81            73
# 14            17            20
# 18             1             1
# 19             2             2
# 16            21            15
# 17            23            12
# 21            10            11
# 22            15            20
# 20             3             2
# 23            13            19

# %%
# Export as JSON
hetio.readwrite.write_graph(subgraph, 'random-subgraph.json.xz')
